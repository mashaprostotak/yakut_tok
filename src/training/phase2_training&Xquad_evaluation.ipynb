# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
from datasets import Dataset
from transformers import AutoTokenizer
import os

def load_and_process_xquad(file_path, tokenizer):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    processed_data = []

    for article in data["data"]:
        for paragraph in article["paragraphs"]:
            context = paragraph["context"]
            for qa in paragraph["qas"]:
                question = qa["question"]
                answer = qa["answers"][0]["text"]

                # Create Q&A format with special tokens
                formatted_text = (
                    f"<|begin_of_text|><sah>Контекст: {context}\n"
                    f"Соруйаан: {question}\n"
                    f"Эппиэт: {answer}<|end_of_text|>"
                )

                # Also store components separately for evaluation
                processed_data.append({
                    "context": context,
                    "question": question,
                    "answer": answer,
                    "text": formatted_text,
                    "context_length": len(tokenizer.encode(context))
                })

    return processed_data

# Load tokenizer and process dataset
tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/yakut-llama2-finetuned")
xquad_data = load_and_process_xquad("/content/drive/MyDrive/Phase3_train_data/xquad_train_sah.json", tokenizer)
dataset = Dataset.from_dict({
    "text": [d["text"] for d in xquad_data],
    "context": [d["context"] for d in xquad_data],
    "question": [d["question"] for d in xquad_data],
    "answer": [d["answer"] for d in xquad_data],
    "context_length": [d["context_length"] for d in xquad_data]
})

# Tokenization function
def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        max_length=1024, 
        padding="max_length",
    )

# Apply tokenization
tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True,
    num_proc=4,
    remove_columns=["text", "context", "question", "answer"]
)
# Out:
# Map (num_proc=4):   0%|          | 0/952 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
# !pip install transformers accelerate --upgrade
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)

# %%
import json
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling
)
from datasets import Dataset
import numpy as np

# 1. Load model and tokenizer
model_path = "/content/drive/MyDrive/yakut-llama2-finetuned"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)

# 2. Enable RoPE scaling for longer contexts
model.config.rope_scaling = {
    "type": "dynamic",  # Dynamic NTK-aware scaling
    "factor": 2.0       # Extend context length by 2x
}
print(f"Updated RoPE scaling: {model.config.rope_scaling}")

# 3. Load and process XQuAD dataset
def load_and_process_xquad(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    processed_data = []

    for article in data["data"]:
        for paragraph in article["paragraphs"]:
            context = paragraph["context"]
            for qa in paragraph["qas"]:
                question = qa["question"]
                answer = qa["answers"][0]["text"]

                # Create Q&A format with special tokens
                formatted_text = (
                    f"<|begin_of_text|><sah>Контекст: {context}\n"
                    f"Соруйаан: {question}\n"
                    f"Эппиэт: {answer}<|end_of_text|>"
                )

                # Store components
                processed_data.append({
                    "text": formatted_text,
                    "context": context,
                    "question": question,
                    "answer": answer
                })

    return processed_data

# Load dataset
xquad_data = load_and_process_xquad("/content/drive/MyDrive/Phase3_train_data/xquad_train_sah.json")
dataset = Dataset.from_list(xquad_data)

# 4. Tokenization function
def tokenize_function(examples):
    tokenized = tokenizer(
        examples["text"],
        truncation=True,
        max_length=4096,  # Increased context length
        padding=False
    )

    # Add answer start positions
    tokenized["answer_starts"] = []
    for text in examples["text"]:
        # Find position of "Эппиэт:" in the text
        answer_start = text.find("Эппиэт:") + len("Эппиэт:")
        # Convert to token position
        char_to_token = tokenized.char_to_token(0, answer_start)
        tokenized["answer_starts"].append(char_to_token if char_to_token is not None else 0)

    return tokenized

# Apply tokenization
tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True,
    batch_size=4,
    num_proc=4,
    remove_columns=["text", "context", "question", "answer"]
)

# 5. Data Collator with Answer Focus
class QADataCollator(DataCollatorForLanguageModeling):
    def __call__(self, features):
        batch = super().__call__(features)

        # Create loss mask to focus only on answer part
        loss_mask = torch.zeros_like(batch["input_ids"])
        for i, feature in enumerate(features):
            if "answer_starts" in feature and feature["answer_starts"] > 0:
                start_idx = feature["answer_starts"]
                loss_mask[i, start_idx:] = 1
            else:
                # If answer start not found, use whole sequence
                loss_mask[i, :] = 1

        batch["labels"] = batch["input_ids"] * loss_mask
        return batch

# 6. Training Configuration (compatible with older versions)
training_args = TrainingArguments(
    output_dir="/content/drive/MyDrive/yakut-qa-finetuned",
    num_train_epochs=10, 
    per_device_train_batch_size=4,
    gradient_accumulation_steps=8,
    learning_rate=3e-5,
    warmup_steps=200,
    weight_decay=0.01,
    fp16=True,
    gradient_checkpointing=True,
    logging_steps=50,
    save_steps=500,
    eval_strategy="no",  # Disable evaluation during training
    load_best_model_at_end=False,
    report_to="none",
    dataloader_num_workers=4,
    max_grad_norm=1.0,
)

# Initialize data collator
data_collator = QADataCollator(
    tokenizer=tokenizer,
    mlm=False
)

# Split dataset
train_test_split = tokenized_dataset.train_test_split(test_size=0.1)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_test_split["train"],
)

# 7. Start training
print("Starting Q&A fine-tuning...")
trainer.train()
trainer.save_model("/content/drive/MyDrive/yakut-qa-finetuned")
print("Fine-tuning complete!")

# 8. Q&A Generation Function
def generate_answer(model, tokenizer, context, question, max_length=256):
    prompt = (
        f"<|begin_of_text|><sah>Контекст: {context}\n"
        f"Соруйаан: {question}\n"
        f"Эппиэт:"
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        max_length=4096,
        truncation=True
    ).to(model.device)

    if 'token_type_ids' in inputs:
        del inputs['token_type_ids']

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_length,
            temperature=0.7,
            top_k=40,
            top_p=0.9,
            repetition_penalty=1.1,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            do_sample=True,
        )

    # Extract only the answer part
    full_output = tokenizer.decode(outputs[0], skip_special_tokens=False)
    answer_start = full_output.find("Эппиэт:") + len("Эппиэт:")
    answer = full_output[answer_start:].split("<|end_of_text|>")[0].strip()

    return answer
# Out:
# Updated RoPE scaling: {'type': 'dynamic', 'factor': 2.0}
# Map (num_proc=4):   0%|          | 0/952 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Starting Q&A fine-tuning...
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
#     <div>
#
#       <progress value='270' max='270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [270/270 17:59, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>4.017500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.300200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.097000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.083300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.065100</td>
#     </tr>
#   </tbody>
# </table><p>
# Fine-tuning complete!

# %%
test_context = "<|begin_of_text|> <sah> Пантердар көмүскэллэрэ 308 эрэ очукуону биэрэн, лигаҕа алтыс миэстэҕэ таҕыста, ону тэҥэ НФЛ-ы 24 очукуолаах уонна түөрт Про Боул талыытынан киэн туттар. Про Боул көмүскэнэр атааката Каванн Шорт 11 охсуунан хамаанданы салайбыта, ону тэҥэ үс охсууну күһэйбитэ уонна иккини ылбыта. Бииргэ үлэлиир линейщик Марио Эддисон 61⁄2 мешогу эбии киллэрдэ. Пантерс линиятыгар өссө бэтэрээн көмүскэнэр Джаред Аллен, 5 төгүллээх профессиональнай боулер, НФЛ 136-нан актыыбынай карьератын салайааччыта, уонна көмүскэнэр Кони Или, 9 эрэ стартка 5 сактаах этэ. Кинилэр кэннилэриттэн, Пантерс үс стартовай лайнбекердарыттан иккитэ эмиэ Про Боулга оонньуурга талыллыбыттара: Томас Дэвис уонна Люк Куечли. Дэвис 51⁄2 сактары, түөрт күһэллибит охсууну уонна түөрт охсууну хомуйбута, оттон Куечли хамаанданы охсуһууга (118) салайбыта, икки күһэллибит охсууну оҥорбута уонна бэйэтин түөрт пастарын быһа охсубута. Каролина иккис хамаандатыгар Pro Bowl куттала суох буолуутун Курт Коулман кыттыбыта, кини хамаанданы карьератын үрдүк көрдөрүүтүнэн сэттэ перехваттаах салайбыта, ону тэҥэ 88 атааканы оҥорбута уонна Pro Bowl угловой защитнига Джош Норман, кини сезоҥҥа хааччахтааһын муннугар кубулуйбута уонна түөрт перехваттаах этэ, олортон иккитэ тачдауннарга төннүбүттэрэ."

test_question = " <|begin_of_text|> <sah> Бу сезоҥҥа хамаандаҕа ким саамай элбэх мешогу суруйда?"

answer = generate_answer(model, tokenizer, test_context, test_question)
print(f"Question: {test_question}")
print(f"Answer: {answer}")
# Out:
# Question:  <|begin_of_text|> <sah> Бу сезоҥҥа хамаандаҕа ким саамай элбэх мешогу суруйда?
# Answer: КаваннШорт

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import re

# 1. Enhanced Yakut Text Reconstruction
def reconstruct_yakut_text(text):
    """Reconstruct Yakut text with proper word boundaries"""
    # Step 1: Add spaces around special tokens
    text = re.sub(r'(<\|[^>]+\|>)', r' \1 ', text)

    # Step 2: Handle known Yakut words and patterns
    yakut_words = [
        "хаһан", "туох", "хэн", "хайдах", "тоҕо", "ылыллыбытай", "сыллаах",
        "сэриитин", "Америка", "Европаҕа", "Монреаль", "Саха", "Республикатын",
        "Дьокуускай", "куоратка", "баар", "Хотугу", "кыргыһыытыттан", "түһэрсиигэ",
        "сыллаахха", "ылыллыбытай"
    ]

    for word in sorted(yakut_words, key=len, reverse=True):
        pattern = re.compile(re.escape(word), re.IGNORECASE)
        text = pattern.sub(r' \g<0> ', text)

    # Step 3: Handle numbers and common suffixes
    text = re.sub(r'(\d+)([а-яё])', r'\1 \2', text)  
    text = re.sub(r'([а-яё])(\d+)', r'\1 \2', text) 
    # Step 4: Handle punctuation
    text = re.sub(r'([.,!?;:])([^\s])', r'\1 \2', text) 
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)         

    # Step 5: Clean up spaces
    text = re.sub(r'\s+', ' ', text) 

    return text.strip()

# 2. Improved Q&A Generation Function
def generate_qa_answer(model, tokenizer, context, question, max_new_tokens=30):
    # Build prompt with proper spacing
    prompt = (
        f"<|begin_of_text|> <sah> Контекст: {context}\n"
        f"Соруйаан: {question}\n"
        f"Эппиэт:"
    )

    # Tokenize with truncation for long contexts
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        max_length=2048,
        truncation=True
    ).to(model.device)

    # Explicitly remove token_type_ids if present
    if 'token_type_ids' in inputs:
        del inputs['token_type_ids']

    # Generate answer
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.7, 
            top_k=40,
            top_p=0.95,
            repetition_penalty=1.1,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            num_beams=5,  
            early_stopping=True,
            do_sample=True,
        )

    # Decode only the generated part
    input_length = inputs.input_ids.shape[1]
    generated_ids = outputs[0][input_length:]
    generated_text = tokenizer.decode(generated_ids, skip_special_tokens=True)

    # Remove any trailing special tokens
    generated_text = generated_text.replace("<|end_of_text|>", "").strip()

    # Apply Yakut text reconstruction
    return reconstruct_yakut_text(generated_text)

# 3. Load Model and Tokenizer
model_path = "/content/drive/MyDrive/yakut-qa-finetuned"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path).to("cuda")

# 4. Test with your example
context = (
    "Пантердар көмүскэллэрэ 308 эрэ очукуону биэрэн, лигаҕа алтыс миэстэҕэ таҕыста, ону тэҥэ НФЛ-ы 24 очукуолаах уонна түөрт Про Боул талыытынан киэн туттар. Про Боул көмүскэнэр атааката Каванн Шорт 11 охсуунан хамаанданы салайбыта, ону тэҥэ үс охсууну күһэйбитэ уонна иккини ылбыта. Бииргэ үлэлиир линейщик Марио Эддисон 61⁄2 мешогу эбии киллэрдэ. Пантерс линиятыгар өссө бэтэрээн көмүскэнэр Джаред Аллен, 5 төгүллээх профессиональнай боулер, НФЛ 136-нан актыыбынай карьератын салайааччыта, уонна көмүскэнэр Кони Или, 9 эрэ стартка 5 сактаах этэ. Кинилэр кэннилэриттэн, Пантерс үс стартовай лайнбекердарыттан иккитэ эмиэ Про Боулга оонньуурга талыллыбыттара: Томас Дэвис уонна Люк Куечли. Дэвис 51⁄2 сактары, түөрт күһэллибит охсууну уонна түөрт охсууну хомуйбута, оттон Куечли хамаанданы охсуһууга (118) салайбыта, икки күһэллибит охсууну оҥорбута уонна бэйэтин түөрт пастарын быһа охсубута. Каролина иккис хамаандатыгар Pro Bowl куттала суох буолуутун Курт Коулман кыттыбыта, кини хамаанданы карьератын үрдүк көрдөрүүтүнэн сэттэ перехваттаах салайбыта, ону тэҥэ 88 атааканы оҥорбута уонна Pro Bowl угловой защитнига Джош Норман, кини сезоҥҥа хааччахтааһын муннугар кубулуйбута уонна түөрт перехваттаах этэ, олортон иккитэ тачдауннарга төннүбүттэрэ."
)
question = "Пантердар көмүскэллэрэ хас очукуону биэрдэ?"

# Generate and print answer
answer = generate_qa_answer(model, tokenizer, context, question)
print(f"Question: {question}")
print(f"Answer: {answer}")

# 5. Test tokenizer decoding
test_cases = [
    "<|begin_of_text|><sah>Монреальхаһанылыллыбытай?",
    "<|begin_of_text|><sah>СахаРеспубликатынкиинэтэДьокуускайкуораткабаар.",
    "<|begin_of_text|><sah>1760сыллаахха",
    "<|begin_of_text|><sah>ХотугуАмерикасэттэсыллаахсэриитинтыйаатырыгар"
]

print("\nTokenizer reconstruction tests:")
for test_text in test_cases:
    decoded = tokenizer.decode(tokenizer.encode(test_text))
    fixed = reconstruct_yakut_text(decoded)
    print(f"Original: {decoded}")
    print(f"Fixed:    {fixed}")
    print("-" * 50)
# Out:
# Question: Монреаль хаһан ылыллыбытай?
# Answer: 1756
#
# Tokenizer reconstruction tests:
# Original: <|begin_of_text|><sah>Монреальхаһанылыллыбытай?
# Fixed:    <|begin_of_text|> <sah> Монреаль хаһан ылыллыбытай?
# --------------------------------------------------
# Original: <|begin_of_text|><sah>СахаРеспубликатынкиинэтэДьокуускайкуораткабаар.
# Fixed:    <|begin_of_text|> <sah> Саха Республикатын киинэтэ Дьокуускай куоратка баар.
# --------------------------------------------------
# Original: <|begin_of_text|><sah>1760сыллаахха
# Fixed:    <|begin_of_text|> <sah>1760 сыллаах ха
# --------------------------------------------------
# Original: <|begin_of_text|><sah>ХотугуАмерикасэттэсыллаахсэриитинтыйаатырыгар
# Fixed:    <|begin_of_text|> <sah> Хотугу Америка сэттэ сыллаах сэриитин тыйаатырыгар
# --------------------------------------------------

# %%
import json
import re
import torch
from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer

# 1. Enhanced Yakut Text Reconstruction
def reconstruct_yakut_text(text):
    """Reconstruct Yakut text with proper word boundaries"""
    # Step 1: Add spaces around special tokens
    text = re.sub(r'(<\|[^>]+\|>)', r' \1 ', text)

    # Step 2: Handle known Yakut words and patterns
    yakut_words = [
        "хаһан", "туох", "хэн", "хайдах", "тоҕо", "ылыллыбытай", "сыллаах",
        "сэриитин", "Америка", "Европаҕа", "Монреаль", "Саха", "Республикатын",
        "Дьокуускай", "куоратка", "баар", "Хотугу", "кыргыһыытыттан", "түһэрсиигэ",
        "сыллаахха", "ылыллыбытай", "контекст", "соруйаан", "эппиэт"
    ]

    for word in sorted(yakut_words, key=len, reverse=True):
        pattern = re.compile(re.escape(word), re.IGNORECASE)
        text = pattern.sub(r' \g<0> ', text)

    # Step 3: Handle numbers and common suffixes
    text = re.sub(r'(\d+)([а-яё])', r'\1 \2', text)  
    text = re.sub(r'([а-яё])(\d+)', r'\1 \2', text)  

    # Step 4: Handle punctuation
    text = re.sub(r'([.,!?;:])([^\s])', r'\1 \2', text)  
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)        

    # Step 5: Clean up spaces
    text = re.sub(r'\s+', ' ', text) 

    return text.strip()

# 2. Improved Q&A Generation Function
def generate_qa_answer(model, tokenizer, context, question, max_new_tokens=30):
    # Build prompt
    prompt = (
        f"<|begin_of_text|> <sah> Контекст: {context}\n"
        f"Соруйаан: {question}\n"
        f"Эппиэт:"
    )

    # Tokenize with truncation for long contexts
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        max_length=2048,
        truncation=True
    ).to(model.device)

    # **Explicitly remove token_type_ids if present**
    if 'token_type_ids' in inputs:
        del inputs['token_type_ids']


    # Generate answer
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.7,
            top_k=40,
            top_p=0.95,
            repetition_penalty=1.1,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            num_beams=5,
            early_stopping=True,
            do_sample=True,
        )

    # Decode only the generated part
    input_length = inputs.input_ids.shape[1]
    generated_ids = outputs[0][input_length:]
    generated_text = tokenizer.decode(generated_ids, skip_special_tokens=True)

    # Remove any trailing special tokens
    generated_text = generated_text.replace("<|end_of_text|>", "").strip()

    # Apply Yakut text reconstruction
    return reconstruct_yakut_text(generated_text)

# 3. Evaluation Metrics
def normalize_text(text):
    """Normalize text for evaluation"""
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = re.sub(r'[.,!?;:()\[\]{}"\'«»]', '', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

def calculate_em(prediction, ground_truth):
    """Calculate Exact Match score"""
    pred_norm = normalize_text(prediction)
    gt_norm = normalize_text(ground_truth)
    return int(pred_norm == gt_norm)

def calculate_f1(prediction, ground_truth):
    """Calculate token-level F1 score"""
    pred_tokens = normalize_text(prediction).split()
    gt_tokens = normalize_text(ground_truth).split()

    # If both are empty, return 1.0
    if len(pred_tokens) == 0 and len(gt_tokens) == 0:
        return 1.0

    # If one is empty, return 0.0
    if len(pred_tokens) == 0 or len(gt_tokens) == 0:
        return 0.0

    # Calculate common tokens
    common_tokens = set(pred_tokens) & set(gt_tokens)

    # Calculate precision and recall
    precision = len(common_tokens) / len(pred_tokens)
    recall = len(common_tokens) / len(gt_tokens)

    # Calculate F1
    if precision + recall > 0:
        f1 = 2 * (precision * recall) / (precision + recall)
    else:
        f1 = 0.0

    return f1

# 4. Load Model and Tokenizer
model_path = "/content/drive/MyDrive/yakut-qa-finetuned"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path).to("cuda")

# 5. Load XQuAD Dataset
def load_xquad_dataset(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    dataset = []
    for article in data["data"]:
        for paragraph in article["paragraphs"]:
            context = paragraph["context"]
            for qa in paragraph["qas"]:
                dataset.append({
                    "id": qa["id"],
                    "context": context,
                    "question": qa["question"],
                    "answer": qa["answers"][0]["text"]
                })
    return dataset

xquad_path = "/content/drive/MyDrive/Phase3_train_data/xquad_test_sah.json" 
xquad_dataset = load_xquad_dataset(xquad_path)
print(f"Loaded {len(xquad_dataset)} QA pairs")

# 6. Run Evaluation
results = []
total_em = 0
total_f1 = 0

for item in tqdm(xquad_dataset, desc="Evaluating"):
    try:
        # Generate answer
        pred_answer = generate_qa_answer(
            model,
            tokenizer,
            item["context"],
            item["question"]
        )

        # Calculate metrics
        em = calculate_em(pred_answer, item["answer"])
        f1 = calculate_f1(pred_answer, item["answer"])

        # Store results
        results.append({
            "id": item["id"],
            "context": item["context"],
            "question": item["question"],
            "predicted_answer": pred_answer,
            "true_answer": item["answer"],
            "em": em,
            "f1": f1
        })

        # Accumulate scores
        total_em += em
        total_f1 += f1

    except Exception as e:
        print(f"Error processing {item['id']}: {str(e)}")
        results.append({
            "id": item["id"],
            "error": str(e)
        })

# 7. Calculate Final Scores
num_samples = len([r for r in results if "em" in r])
avg_em = total_em / num_samples if num_samples > 0 else 0
avg_f1 = total_f1 / num_samples if num_samples > 0 else 0

print("\nEvaluation Results:")
print(f"Exact Match (EM): {avg_em:.4f}")
print(f"F1 Score: {avg_f1:.4f}")

# 8. Save Detailed Results
results_path = "xquad_evaluation_results.json"
with open(results_path, 'w', encoding='utf-8') as f:
    json.dump({
        "metrics": {"em": avg_em, "f1": avg_f1},
        "details": results
    }, f, ensure_ascii=False, indent=2)

print(f"Detailed results saved to {results_path}")

# 9. Print Sample Results
print("\nSample Predictions:")
for i, result in enumerate(results[:5]):
    if "error" not in result:
        print(f"Question: {result['question']}")
        print(f"True Answer: {result['true_answer']}")
        print(f"Predicted Answer: {result['predicted_answer']}")
        print(f"EM: {result['em']}, F1: {result['f1']:.4f}")
        print("-" * 80)
# Out:
# Loaded 238 QA pairs
# Evaluating: 100%|██████████| 238/238 [01:50<00:00,  2.15it/s]
# Evaluation Results:
# Exact Match (EM): 0.0588
# F1 Score: 0.0841
# Detailed results saved to xquad_evaluation_results.json
#
# Sample Predictions:
# Question: Монреаль хаһан ылыллыбытай?
# True Answer: 1760
# Predicted Answer: 1754
# EM: 0, F1: 0.0000
# --------------------------------------------------------------------------------
# Question: Дойду тугунан биллэрий?
# True Answer: орто уонна уһун дистанциялаах чэпчэки атлетикаҕа баһыйар оруола
# Predicted Answer: Кения
# EM: 0, F1: 0.0000
# --------------------------------------------------------------------------------
# Question: Ханнык хамаанда МЛС-тан уһуллубутай?
# True Answer: Чивас
# Predicted Answer: 2018
# EM: 0, F1: 0.0000
# --------------------------------------------------------------------------------
# Question: 2005 сылтан ыла, Доктор Ким сүрүн айанныыр киһитэ хайдаҕый?
# True Answer: дьахтар
# Predicted Answer: СтивенМоффат
# EM: 0, F1: 0.0000
# --------------------------------------------------------------------------------
# Question: Культураҕа өрөбөлүүссүйэлээх гражданскай истибэт буолуу ким холобурунан бэлиэтэнэр?
# True Answer: Ганди
# Predicted Answer: Венгрдар
# EM: 0, F1: 0.0000
# --------------------------------------------------------------------------------

# %%
# Print all question/true answer and generated answer pairs
print("\nAll Question/Answer Pairs:")
for result in results:
    if "error" not in result:
        print(f"Question: {result['question']}")
        print(f"True Answer: {result['true_answer']}")
        print(f"Predicted Answer: {result['predicted_answer']}")
        print("-" * 80)
    else:
        print(f"Skipping item {result['id']} due to error: {result['error']}")
        print("-" * 80)
# Out:
# All Question/Answer Pairs:
# Question: Монреаль хаһан ылыллыбытай?
# True Answer: 1760
# Predicted Answer: 1754
# --------------------------------------------------------------------------------
# Question: Дойду тугунан биллэрий?
# True Answer: орто уонна уһун дистанциялаах чэпчэки атлетикаҕа баһыйар оруола
# Predicted Answer: Кения
# --------------------------------------------------------------------------------
# Question: Ханнык хамаанда МЛС-тан уһуллубутай?
# True Answer: Чивас
# Predicted Answer: 2018
# --------------------------------------------------------------------------------
# Question: 2005 сылтан ыла, Доктор Ким сүрүн айанныыр киһитэ хайдаҕый?
# True Answer: дьахтар
# Predicted Answer: СтивенМоффат
# --------------------------------------------------------------------------------
# Question: Культураҕа өрөбөлүүссүйэлээх гражданскай истибэт буолуу ким холобурунан бэлиэтэнэр?
# True Answer: Ганди
# Predicted Answer: Венгрдар
# --------------------------------------------------------------------------------
# Question: Фаунальнай сукцессия принцибэ ким принциптэригэр олоҕурбутай?
# True Answer: Уильям Смит
# Predicted Answer: Фаунальнайсукцессияпринцибэ
# --------------------------------------------------------------------------------
# Question: Англия хаһан Францияҕа сэриини биллэрбитэй?
# True Answer: Ыам ыйын 18 күнэ, 1756 с.
# Predicted Answer: 1756
# --------------------------------------------------------------------------------
# Question: Ханнык Доктор Кто Доктор Кто суох суруллубутай?
# True Answer: Далектар кырыыстара
# Predicted Answer: ДэвидБэнкс
# --------------------------------------------------------------------------------
# Question: Чингисхаан өлөрүгэр илин диэки ханнык муоранан кыраныыссалаабытай?
# True Answer: Япония муората
# Predicted Answer: Каспийскаймуора
# --------------------------------------------------------------------------------
# Question: Чингисхан ханнык удьуора Багдады былдьаабытай?
# True Answer: Хулагу Хаан
# Predicted Answer: Футбол
# --------------------------------------------------------------------------------
# Question: Үрдүк тэҥэ суох буолуулаах дойду тугу ситиһэригэр өр кэм нааданый?
# True Answer: дьадаҥы буолууну икки аҥы кыччатыы
# Predicted Answer: туспакыһамньы
# --------------------------------------------------------------------------------
# Question: Тесла хампаанньатын тэрийэн баран бастаан тугу ылбытай?
# True Answer: патеннар
# Predicted Answer: электрическэйдугалаахсырдыккаолоҕурбутсырдатыысистиэмэлэрэ
# --------------------------------------------------------------------------------
# Question: Примитивнай үөстээх сүһүөхтээх харамайдар икки холобурдара ханныктарый?
# True Answer: лампрей уонна балык
# Predicted Answer: адаптивнайиммуннайсистиэмэ
# --------------------------------------------------------------------------------
# Question: Гарвард стадиона ханна баарый?
# True Answer: Оллстон
# Predicted Answer: Кембридж
# --------------------------------------------------------------------------------
# Question: Норманнар замоктарын аата ким этэй?
# True Answer: Афранджи
# Predicted Answer: АмальфиуоннаБари
# --------------------------------------------------------------------------------
# Question: Амазонка тропическай тропическай ойууругар мас көрүҥүн ахсаана төһө буолуой?
# True Answer: 16,000
# Predicted Answer: 16, 000
# --------------------------------------------------------------------------------
# Question: Тоҕо коллекцияҕа ураты түгэннэргэ анаан тигиллибит муода таҥастара баһыйалларый?
# True Answer: Тоҕо диэтэххэ, урукку кэмнэртэн күннээҕи таҥас уопсайынан тыыннаах хаалбатаҕа
# Predicted Answer: 1442
# --------------------------------------------------------------------------------
# Question: Пакеттар хайдах ыытыллалларый
# True Answer: биирдиилээн
# Predicted Answer: Пакеттиийэрсиригэр туох буоларый
# --------------------------------------------------------------------------------
# Question: Ctenophora хас көрүҥэ бигэргэммитэй?
# True Answer: 100–150
# Predicted Answer: 100–150 көрүҥ
# --------------------------------------------------------------------------------
# Question: Оонньуур паар массыыналарыгар ханнык сылытар элемены элбэхтик тутталларый?
# True Answer: электрическэй
# Predicted Answer: күн
# --------------------------------------------------------------------------------
# Question: Ханнык баҕарар түмүк хайдах уратытык көрдөрүллүөн сөбүй?
# True Answer: сүрүн түмүктэр холбоһуктаах суумаларын быһыытынан
# Predicted Answer: сүрүнтүмүктэр
# --------------------------------------------------------------------------------
# Question: Ханнык немец архитекторыгар музей бырайыагын оҥорорго соруйбуттарай?
# True Answer: Готфрид Семпер
# Predicted Answer: Оҥоронтаһаарыылармузейдара
# --------------------------------------------------------------------------------
# Question: Европа сойууһун тэрийэр сүрүн дуогабардар хайдах саҕаламмыттарай?
# True Answer: чох уонна тимир уопсай быраабылаларын кытта
# Predicted Answer: чохуоннатимируопсайбыраабылалара
# --------------------------------------------------------------------------------
# Question: Палеоклиматологтар ханнык күн-дьыл уратытын туһунан информацияны баҕаралларый?
# True Answer: климат
# Predicted Answer: Электрическэйтокдиэнэлектрическэйзарядуларыйыытынбириэмэтэ
# --------------------------------------------------------------------------------
# Question: Цианобактериялар клеткаҕа төһө өр киирбиттэрий?
# True Answer: миллиард сыл анараа өттүгэр
# Predicted Answer: 565 сылтан 1534 сылгадиэри
# --------------------------------------------------------------------------------
# Question: Кэнники кэм аата ким диэний?
# True Answer: Голоцен
# Predicted Answer: саамайкэнникикэмикыччатар
# --------------------------------------------------------------------------------
# Question: Ньюкасл куорат киининэн ханнык тоннеллар тутуллалларый?
# True Answer: дириҥ таһымнаах
# Predicted Answer: Ньюкаслтимирсуолситимэ
# --------------------------------------------------------------------------------
# Question: Аарон Спеллинг ханнык драмата 80-с сылларга ABC ханаалга тахсыбытай?
# True Answer: Династия
# Predicted Answer: ХолбоһуктаахABC1981
# --------------------------------------------------------------------------------
# Question: ABC түөрт ноталаах ырыата ханна билигин да туттулларый?
# True Answer: ABC по запросу
# Predicted Answer: ПиттардСалливан
# --------------------------------------------------------------------------------
# Question: Манакинтаунҥа хас олохтоох киһи олохсуйбутай?
# True Answer: 390
# Predicted Answer: тоҕус
# --------------------------------------------------------------------------------
# Question: Икбал хас сыллаахха Лахорга төннүбүтэй?
# True Answer: 1908
# Predicted Answer: 1908
# --------------------------------------------------------------------------------
# Question: Сири эбэтэр баайы-дуолу хайдах туһаныахха сөбүн ким быһаарарый?
# True Answer: Шотландия бырабыыталыстыбата.
# Predicted Answer: эксперимент
# --------------------------------------------------------------------------------
# Question: Эйнштейн ханнык физика моделын оҥорботоҕой?
# True Answer: бэйэтэ сөп түбэһэр түмсүү
# Predicted Answer: Физик
# --------------------------------------------------------------------------------
# Question: Музыкальнай инструменнар галереяларын сабыыга эппиэттиир Ил Түмэн саайтыгар онлайн-петицияҕа төһө киһи илии баттаата?
# True Answer: 5100 тахса
# Predicted Answer: 4100
# --------------------------------------------------------------------------------
# Question: Коммерческай туһаныыга уустук кислород хаһан оҥоһуллубутай?
# True Answer: 1895
# Predicted Answer: 1891
# --------------------------------------------------------------------------------
# Question: Полония дьиэтэ ханна баарый?
# True Answer: Конвикторскай уул.
# Predicted Answer: Шотландияпарламенын
# --------------------------------------------------------------------------------
# Question: Маккинзи уонна хампаанньаны ким тэрийбитэй?
# True Answer: Джеймс О. Маккинзи
# Predicted Answer: ДжонКорзин
# --------------------------------------------------------------------------------
# Question: Сайыҥҥы тыйаатыр ханна баара буолла?
# True Answer: Саксонскай саад
# Predicted Answer: Момус
# --------------------------------------------------------------------------------
# Question: Амазонка ойууругар аан дойду углерода төһө кээмэйэ мунньулларый?
# True Answer: 10%
# Predicted Answer: 1, 1C3
# --------------------------------------------------------------------------------
# Question: 1935 сыл кэнниттэн ким Рейнландка киирэрин бобуохтарай?
# True Answer: Германия аармыйата
# Predicted Answer: Рейнланд
# --------------------------------------------------------------------------------
# Question: Ханнык биллэр ааптар суруйуутугар Перси Шелли майгыннаһыытын уонна майгыннаһыытын туһаммытай?
# True Answer: Генри Дэвид Торо
# Predicted Answer: Шелли
# --------------------------------------------------------------------------------
# Question: Брукхейвен ханнык сирэ билигин даҕаны буруйу оҥоруу үрдүк таһымынан биллэрий?
# True Answer: Изолированнай подразделение
# Predicted Answer: үрдүкпальмалар
# --------------------------------------------------------------------------------
# Question: Тесла хас сыллаахха өлбүтэй?
# True Answer: 1943
# Predicted Answer: 1943
# --------------------------------------------------------------------------------
# Question: Иммунодефицит тугу үөскэтэрий?
# True Answer: хатыланар уонна олоххо кутталлаах инфекциялар
# Predicted Answer: иммуннайсистиэмэүгэстэр
# --------------------------------------------------------------------------------
# Question: Амазонка ойуура диэн ханнык ойууруй?
# True Answer: сииктээх киэҥ сэбирдэхтээх ойуур
# Predicted Answer: Соҕуруу Америка ҕа
# --------------------------------------------------------------------------------
# Question: Франция өрөспүүбүлүкэлэрэ Франция империятын тутууну хаһан өйөөбүттэрий?
# True Answer: Германия бэйэтин колониальнай империятын тутар буолбутугар
# Predicted Answer: 1830
# --------------------------------------------------------------------------------
# Question: 1955 сыллаахха тахсыбыт ырытыыга олоҕуран, баайдар мунньуллубут харчылара тугу саптарар дии саныыллара буолла?
# True Answer: атыылаһааччы ирдэбилэ кыччаабыт
# Predicted Answer: 1970-ссыллар
# --------------------------------------------------------------------------------
# Question: Бурджесс сланецыгар булуллубут окаменелостарга туох тиийбэт этэй?
# True Answer: щупальцалар
# Predicted Answer: Үс
# --------------------------------------------------------------------------------
# Question: Ханнык оонньооччу 2-тэн мээчиги киллэрбитий?
# True Answer: Андерсон
# Predicted Answer: Ньютон
# --------------------------------------------------------------------------------
# Question: Суперкубокка оонньообут саамай кырдьаҕас квартербек рекордун ким тутан олорбутай?
# True Answer: Джон Элвей
# Predicted Answer: Бронкос
# --------------------------------------------------------------------------------
# Question: 1999 сыллаахха тахсыбыт ыстатыйа информациятын ханнык реконструкциялар өйөөтүлэр?
# True Answer: Джонс уонна атыттар 1998, Поллак, Хуанг уонна Шен 1998, Кроули уонна Лоуэри 2000 уонна Бриффа 2000
# Predicted Answer: "Тыһыынча сыллаах Хотугу полушариетемпературатынсаҥардыы"
# --------------------------------------------------------------------------------
# Question: Тэмүджин хаһан монголлар хааннарынан талыллыбытай?
# True Answer: 1186
# Predicted Answer: 1186
# --------------------------------------------------------------------------------
# Question: Ктенофордар күҥҥэ төһөнү сииллэрий?
# True Answer: бэйэлэрин ыйааһыннарыттан уон төгүл элбэх
# Predicted Answer: 100–150 көрүҥ
# --------------------------------------------------------------------------------
# Question: Паар турбинатын турбинаҕа киирэр температурата төһө буоларый, кыраадыһынан?
# True Answer: 565 °C
# Predicted Answer: 565�C
# --------------------------------------------------------------------------------
# Question: Бастакы интернет2 ситимэ ким диэн ааттаах этэй
# True Answer: Абилин
# Predicted Answer: Интернет 2Ситимэ
# --------------------------------------------------------------------------------
# Question: Илиҥҥи Европа ханнык улахан куораттара монголлар саба түспүттэрэй?
# True Answer: Новгород уонна Псков
# Predicted Answer: Палестина
# --------------------------------------------------------------------------------
# Question: Тоҕус уонна Онус быраастар иккис табаарыстара кимнээх этилэр?
# True Answer: Микки Смит (Ноэль Кларк) уонна Джек Харкнесс (Джон Барроуман)
# Predicted Answer: БиллоруолунтолорорПерлМакки
# --------------------------------------------------------------------------------
# Question: Аюрбарвада уола ким этэй?
# True Answer: Гэгээн Хаан
# Predicted Answer: Байджу
# --------------------------------------------------------------------------------
# Question: АХШ-ка оскуолалары ханнык суут дьыалата араарбытай?
# True Answer: Браун утары Топика үөрэҕириитин сэбиэтин
# Predicted Answer: Соҕуруу
# --------------------------------------------------------------------------------
# Question: Ханнык биллэр индеец дьайыылара гражданскай истибэтэх буолуунан ааҕыллыбыттарай?
# True Answer: Ганди
# Predicted Answer: Венгрдар
# --------------------------------------------------------------------------------
# Question: Дюкен Сен-Пьеры босхолуурга төһө киһини ыыппытай?
# True Answer: 40
# Predicted Answer: 1754
# --------------------------------------------------------------------------------
# Question: Джон Шипшенкс музейга улахан наследствотын сыала-соруга туох этэй?
# True Answer: 'Британскай искусство национальнай галереятын' тэрийии
# Predicted Answer: худуоһунньуктар: Британия
# --------------------------------------------------------------------------------
# Question: Уһун дистанцияҕа сүүрүү эйгэтигэр ким баһыйарый?
# True Answer: Кения спортсменнара (ордук Календжин)
# Predicted Answer: Кения
# --------------------------------------------------------------------------------
# Question: Sky Movies уонна Sky Box office эмиэ ханнык эбии саундтректары киллэрэллэрий?
# True Answer: Dolby Digital
# Predicted Answer: HDматырыйаал
# --------------------------------------------------------------------------------
# Question: SR 99 судаарыстыбалар икки ардыларынааҕы стандартарга сөп түбэһиннэрэн тупсарыы баҕатыгар туох биричиинэлэр дьайалларый?
# True Answer: SR 99 устун куораттарга нэһилиэнньэ ахсаана уонна тырааныспар түргэнник элбиирэ, ону тэҥэ федеральнай үбүлээһин баҕалаах буолуута
# Predicted Answer: Государственнаймаршрут 99
# --------------------------------------------------------------------------------
# Question: Ханнык кэм-кэм суола космоска токур линия быһыытынан көрүллэрий?
# True Answer: баллистическай траектория
# Predicted Answer: аандойду
# --------------------------------------------------------------------------------
# Question: Ыйааһыннар уонна кээмэйдэр генеральнай конференциялара 1960 сыллаахха Тесла аатынан туох диэн ааттаммытай?
# True Answer: Магнитнай поток тыыһыынчатын SI биригээдэтэ
# Predicted Answer: НаучнайситиһиилэриттэнуратыТесла
# --------------------------------------------------------------------------------
# Question: V&A ханнык аан дойду быыстапкатыттан төрүттэммитэй?
# True Answer: 1851 сыллааҕы Улахан быыстапка
# Predicted Answer: Оҥоронтаһаарыылармузейдара
# --------------------------------------------------------------------------------
# Question: DECnet бастаан тугу оҥорбутай
# True Answer: икки PDP-11 мини-компьютеры холбоо
# Predicted Answer: PhaseII(1982)
# --------------------------------------------------------------------------------
# Question: НАСА ханнык сирэ LOR идеятыгар бүтэһигин кэлбитэй?
# True Answer: Маршалл космическай көтөр киинэ
# Predicted Answer: Саурид
# --------------------------------------------------------------------------------
# Question: Судаарыстыбаннай оскуолалары кытта, Соҕуруу Африка оскуолаларын туһунан сокуонунан ханнык оскуола билиниллибитэй?
# True Answer: тутулуга суох
# Predicted Answer: үгэсбуолбутчааһынай
# --------------------------------------------------------------------------------
# Question: Америкаҕа үһүс баай киһи кимий?
# True Answer: Ларри Эллисон
# Predicted Answer: ЛарриЭллисон
# --------------------------------------------------------------------------------
# Question: WG I Summary for Policymakers отчуотугар киһи дьайыыта парниковай гаастарга туох дьайыылаах диэн этиллэрий?
# True Answer: атмосфера мунньуллуутун биллэ үрдэтии
# Predicted Answer: аандойдуортосалгынынтемпературата
# --------------------------------------------------------------------------------
# Question: Ким 1915 сыллаахха атыыласпытай?
# True Answer: Эдисон
# Predicted Answer: Тесла
# --------------------------------------------------------------------------------
# Question: Ханнык спутник Sky Digital саҥа цифровой сервиһи таһаарарга көмөлөспүтэй?
# True Answer: Eutelsat's Eurobird 1
# Predicted Answer: 28. 5
# --------------------------------------------------------------------------------
# Question: Кузнецовскай кривая этэринэн, экэниэмикэ сайдыытын кытта, тэҥэ суох буолуу туох кэнниттэн аҕыйыаҕай?
# True Answer: бастакы улаатар
# Predicted Answer: "магиялаах"
# --------------------------------------------------------------------------------
# Question: Виктория парламена ханнык докумуонтан тэриллибитэй?
# True Answer: Виктория Конституциятын сокуона 1855
# Predicted Answer: "олохтоох"положениялар
# --------------------------------------------------------------------------------
# Question: Тесла олоҕун үгүс өттүгэр ханна олорбутай?
# True Answer: Нью-Йорк гостиницалара
# Predicted Answer: сүтэнэрэрдии
# --------------------------------------------------------------------------------
# Question: Y бастакы вариана хайдах уонна хаһан тахсыбыта. pestis Европа5а киирэр да?
# True Answer: Марсель пордунан 1347 сыллаахха ахсынньы эргин
# Predicted Answer: 1349
# --------------------------------------------------------------------------------
# Question: Никсон кинини хаһан талбытай?
# True Answer: 1973
# Predicted Answer: 1974
# --------------------------------------------------------------------------------
# Question: Джон Элуэй Суперкубок XXXIII оонньууругар хас саастаах этэй?
# True Answer: 38
# Predicted Answer: 38
# --------------------------------------------------------------------------------
# Question: Кытай националистара инники күөҥҥэ сылдьар Кытай хомуньуус күүстэриттэн мавзолейы ханна көһөрбүттэрий?
# True Answer: Синин аттыгар баар Кумбум манастыыра эбэтэр Таэр Ши
# Predicted Answer: ДуншаньДафоДиан
# --------------------------------------------------------------------------------
# Question: Эдиакарнай эоандромеда тугу көрдөрөрүнэн ааҕыллыан сөбүй?
# True Answer: тараах желе.
# Predicted Answer: көрүҥүылыахха
# --------------------------------------------------------------------------------
# Question: Ганди үлэтэ туох диэн ааттаах этэй?
# True Answer: Сатьяграха
# Predicted Answer: Ганди
# --------------------------------------------------------------------------------
# Question: Пейтон Мэннинг Суперкубок 50 оонньуутугар хас саастаах этэй?
# True Answer: 39
# Predicted Answer: 39
# --------------------------------------------------------------------------------
# Question: ТУМАС президена кимий?
# True Answer: Преподобнай Пол Т. Столсуорт
# Predicted Answer: Шотландияпарламенын
# --------------------------------------------------------------------------------
# Question: Дойду гимнын ким ыллаабытай?
# True Answer: Леди Гага
# Predicted Answer: ЛедиГага
# --------------------------------------------------------------------------------
# Question: BSkyB стандартнай быһаарыылаах биэриилэрэ туохха сөп түбэһэллэрий?
# True Answer: DVB-га сөп түбэһэр MPEG-2
# Predicted Answer: DVB-гасөптүбэһэр
# --------------------------------------------------------------------------------
# Question: Бу кылгас болдьохтоох тэрилтэ тоҕо тэриллибитэй?
# True Answer: эмбаргоҕа эппиэти сөп түбэһиннэрэргэ
# Predicted Answer: УильямЭ. Саймон
# --------------------------------------------------------------------------------
# Question: Бастакы методистскай духовенствоны ким анаабытай?
# True Answer: Джон Уэсли
# Predicted Answer: Уэсли
# --------------------------------------------------------------------------------
# Question: Виктория арҕаа өттүгэр сорох линиялар төһө кээмэйгэ уларыйбыттарай?
# True Answer: 1,435 мм (4 фут 8 1⁄2 дюйм) стандартнай калибр
# Predicted Answer: 1435 мм(4 фут 3 дюйм)тардыылаахлиниялар
# --------------------------------------------------------------------------------
# Question: Илиҥҥи Германия бүтэһик премьер-миниистирэ ким этэй?
# True Answer: Лотар де Мезьер
# Predicted Answer: АдольфГалланд
# --------------------------------------------------------------------------------
# Question: Фаунальнай сукцессия принцибэ ким эволюциятын теориятыттан 100 сыл иннинэ оҥоһуллубутай?
# True Answer: Чарльз Дарвин
# Predicted Answer: УильямСмит
# --------------------------------------------------------------------------------
# Question: 2015 сыллаахха Пантердар көмүскэллэрэ төһө перехваттары оҥорбуттарай?
# True Answer: 24
# Predicted Answer: 24
# --------------------------------------------------------------------------------
# Question: Паар массыынатын үлэтин бэрэбиэркэлииргэ ханнык тэрил туттулларый?
# True Answer: паровой двигатель индикатора
# Predicted Answer: ЧарльзПортер
# --------------------------------------------------------------------------------
# Question: Чингисхан удьуордарыттан ким мамлюктары Палестинаттан үүрэн таһаарбытай?
# True Answer: Газан Хан
# Predicted Answer: Футбол
# --------------------------------------------------------------------------------
# Question: Билиҥҥи ктенфора суох ктенфораларын көрдөрөр туох окаменелостары булбуттарай?
# True Answer: щупальцалар
# Predicted Answer: щупальцалар
# --------------------------------------------------------------------------------
# Question: 2000 сыллаахха Амазонка ойуурун хас квадратнай килэмиэтирэ сүппүтэ буолла?
# True Answer: 587,000
# Predicted Answer: 415, 000
# --------------------------------------------------------------------------------
# Question: Төрөппүт уоппускатын директивата хаһан оҥоһуллубутай?
# True Answer: 1996
# Predicted Answer: 1997
# --------------------------------------------------------------------------------
# Question: Проблемнай экземпляр строкатын атын термина тугуй?
# True Answer: битстрокалар
# Predicted Answer: кыһалҕалаахтүбэлтэ
# --------------------------------------------------------------------------------
# Question: Европа Сэбиэтэ хаһан биир тэрилтэҕэ Киһи быраабыгар Европа хартыынатын оҥорорго сорудахтаабытай?
# True Answer: 1999
# Predicted Answer: КиһибыраабыгарЕвропасуутун
# --------------------------------------------------------------------------------
# Question: Виктория конституциятыгар ханнык бөлөх уларытыан сөбүй?
# True Answer: Виктория парламена
# Predicted Answer: "олохтоох"положениялар
# --------------------------------------------------------------------------------
# Question: Кирни бульвара ким аатынан ааттаммытай?
# True Answer: М. Тео Кирни
# Predicted Answer: Фресноуулуссатын
# --------------------------------------------------------------------------------
# Question: Муора уутуттан иһэр ууну перегонкалыыр туһунан ким суруйбутай?
# True Answer: Аль-Муваффак
# Predicted Answer: Шотландияпарламенын
# --------------------------------------------------------------------------------
# Question: Норманнар Анатолияҕа кимниин холбоспуттарай?
# True Answer: Турция күүстэрэ
# Predicted Answer: АмальфиуоннаБари
# --------------------------------------------------------------------------------
# Question: Элвей 38 сааһыгар ханнык Супербоулга кыайбытай?
# True Answer: Супербоул XXXIII
# Predicted Answer: ДжонЭлвей
# --------------------------------------------------------------------------------
# Question: Амазонка ойуурдара Сир ойуурдарын төһө ахсаанын ылалларый?
# True Answer: аҥарыттан тахса
# Predicted Answer: 16, 000
# --------------------------------------------------------------------------------
# Question: Мартин Лютер саҕана туох ирдэнэр этэй?
# True Answer: Немец тыллаах таһаарыылар
# Predicted Answer: немецтылынуонналитературатынсайдыыта
# --------------------------------------------------------------------------------
# Question: Исламскай судаарыстыба 2014 сыллаахха бэйэтин туох диэн биллэрбитэй?
# True Answer: халифат
# Predicted Answer: Исламскайсудаарыстыбата
# --------------------------------------------------------------------------------
# Question: Мельбурн рабочай кылаастаах куорат таһынааҕы бөһүөлэктэригэр ханнык политическай баартыйа саамай күүстээх буолуой?
# True Answer: Австралия лейбористскай партията
# Predicted Answer: Либеральнай баар тыйа
# --------------------------------------------------------------------------------
# Question: Ханнык хампаанньаҕа оригинальнай ленталары төннөрө сатыыр сорудах бэриллибитэй?
# True Answer: Лоури Диджитал
# Predicted Answer: CBSNewsүрдүгэр
# --------------------------------------------------------------------------------
# Question: Аан дойдуга бары ископаемайдар биир кэмҥэ булуллубаттара бу принцип туох буоларыгар тириэрдэр?
# True Answer: комплекс
# Predicted Answer: Фаунальнайсукцессияпринцибэ
# --------------------------------------------------------------------------------
# Question: ЮАР хамсааһыныттан тэйии хаһан буолбутай?
# True Answer: 1980-с сыллар бүтүүлэригэр
# Predicted Answer: биэссыл
# --------------------------------------------------------------------------------
# Question: Тесла электрическэй ыытааччы патенын хаһан ылбытай?
# True Answer: 1900
# Predicted Answer: 1901
# --------------------------------------------------------------------------------
# Question: Ханнык биллэр индеец гражданскай непокорность оҥорбутай?
# True Answer: Ганди
# Predicted Answer: Шелли
# --------------------------------------------------------------------------------
# Question: Бу бырачыастартан үгүстэрэ туох сыаллаахтарый?
# True Answer: боппуруостарын остуолга таһаар
# Predicted Answer: систиэмэүлэлииригэр
# --------------------------------------------------------------------------------
# Question: Массыыналары туһаныытын таһынан, соҕуруу Калифорния өссө тугу туһаныытынан биллэрий?
# True Answer: улахан суоллар
# Predicted Answer: иккиулаханоройуоннар
# --------------------------------------------------------------------------------
# Question: Биирдиилээн гражданскай истибэт буолуу сыала-соруга тугуй?
# True Answer: сорох сокуоннары дьайыыта суох оҥорор
# Predicted Answer: Революционнайасуохгражданскайистибэтэхбуолуу
# --------------------------------------------------------------------------------
# Question: Ресницалар туохха туттулларый?
# True Answer: хамсаныы ньымата
# Predicted Answer: ресницалар
# --------------------------------------------------------------------------------
# Question: Джеральд Ратнер атлетика киинэ хаһан тутуллубутай?
# True Answer: 2003
# Predicted Answer: 1999
# --------------------------------------------------------------------------------
# Question: Людвиг Мис ван дер Роэ ханнык дьаһалтаны тутарга анаабытай?
# True Answer: Социальнай сулууспа салалтатын оскуолата
# Predicted Answer: Харрисуопсастыбаннайбэлиитикэниүөрэтэроскуолата
# --------------------------------------------------------------------------------
# Question: Бразилия аан дойдуга соя оҥоһуутугар ханна турарый?
# True Answer: аан дойдуга иккис улахан оҥорон таһаарааччы
# Predicted Answer: 91%
# --------------------------------------------------------------------------------
# Question: Анархистар туох биричиинэнэн накаастабылы ылыныахтарын баҕарбаттарый?
# True Answer: атын дьон быраабын кэспэт
# Predicted Answer: тустаахсокуонсокуоннайа
# --------------------------------------------------------------------------------
# Question: Ханнык Пантерс оонньооччута пенальтины ылбытай, ол Бронкостарга саҥа түһүүлэри биэрбитэ?
# True Answer: Джош Норман
# Predicted Answer: Андерсон
# --------------------------------------------------------------------------------
# Question: Стратиграфтар ханнык көрүҥнээх хостооһун сирдэрин була сатыылларый?
# True Answer: углеводород
# Predicted Answer: стратиграфтар
# --------------------------------------------------------------------------------
# Question: Джексонвилл ханнык историческай киһи аатынан ааттаммытай?
# True Answer: Эндрю Джексон
# Predicted Answer: Джексонвилл
# --------------------------------------------------------------------------------
# Question: Хлоропласт ДНК-тын синонима диэн тугуй?
# True Answer: пластома
# Predicted Answer: ctDNA, эбэтэрcpDNA
# --------------------------------------------------------------------------------
# Question: Соҕурууҥҥу Калифорния нэһилиэнньэлээх пууннара улахан, тарҕаммыт буолаллара биллэр, уонна өссө туох майгылаахтарый?
# True Answer: куорат таһынааҕы
# Predicted Answer: киэҥсирдэр
# --------------------------------------------------------------------------------
# Question: Ураган күүстэрин кээмэйдиир шкаланы туох диэн ааттыылларый?
# True Answer: Саффир-Симпсон шкалата
# Predicted Answer: Джексонвилл
# --------------------------------------------------------------------------------
# Question: Энергипроект АБ мотуора үрдүк баттааһыннаах мотуор эффективноһын хас бырыһыанын ситиспитий?
# True Answer: 27-30%
# Predicted Answer: 8. 8
# --------------------------------------------------------------------------------
# Question: Перотти 1996 сыллаахха оҥорбут чинчийиитэ тугу чинчийбитэй?
# True Answer: тэҥэ суох буолуу экономическай үүнүүгэ дьайыан сөптөөх ханааллар
# Predicted Answer: ааҕылларуоннаүүнүүнамыһах
# --------------------------------------------------------------------------------
# Question: Гражданскай истибэтэхтэргэ сороҕор туох накаастабыл оҥоһулларый?
# True Answer: сөбүлэһии
# Predicted Answer: борокуратуура
# --------------------------------------------------------------------------------
# Question: Монголлар хаьан Траннарга хотторбуттарай?
# True Answer: 1288
# Predicted Answer: ХубилайЯпонияҕа
# --------------------------------------------------------------------------------
# Question: Соҕуруу Африка оскуолаларын туһунан сокуон хас сыллаахха ылыллыбытай?
# True Answer: 1996
# Predicted Answer: 1996
# --------------------------------------------------------------------------------
# Question: 1700-с сылларга Францияттан хас гугенот куоппутай?
# True Answer: 500,000
# Predicted Answer: 100, 000 киһи
# --------------------------------------------------------------------------------
# Question: Кипиддидтар диэн туох буолбатахтарый?
# True Answer: монофилетическай
# Predicted Answer: цидиппидтар
# --------------------------------------------------------------------------------
# Question: Лютер бүтэһик этиитин ханнык чааһа немецтии этэй?
# True Answer: "Биһиги умнаһыттарбыт,"
# Predicted Answer: Венгрдар
# --------------------------------------------------------------------------------
# Question: Sentanta Sports ханнык платформаҕа тахсар былааннаах этэй?
# True Answer: цифровой сирдээҕи
# Predicted Answer: Sports
# --------------------------------------------------------------------------------
# Question: Диатомнар ханнык хлоропластардаахтарый?
# True Answer: кыһыл уу үүнээйитин хлоропласта
# Predicted Answer: күөхууүөнүн
# --------------------------------------------------------------------------------
# Question: Ханнык Ил Түмэн чилиэнэ музей коллекцияны хайдах харыстыаҕын уонна дьон-сэргэ көрөрүгэр таһаарыаҕын быһаарбытай?
# True Answer: Брайан Дэвис
# Predicted Answer: Хорниманмузейыгар
# --------------------------------------------------------------------------------
# Question: Сайыҥҥы тыйаатыр төһө өр үлэлээтэ?
# True Answer: 1870 сылтан 1939 сылга диэри
# Predicted Answer: Момус
# --------------------------------------------------------------------------------
# Question: Варшава бастакы биржата хаһан тэриллибитэй?
# True Answer: 1817
# Predicted Answer: 1817
# --------------------------------------------------------------------------------
# Question: Швейцария реформатын ханнык салайааччыта Лефевр үөрэнээччитэ этэй?
# True Answer: Уильям Фарель
# Predicted Answer: Джеймсөрүс
# --------------------------------------------------------------------------------
# Question: NTL өҥөлөрө туох диэн уларыйбыттарай?
# True Answer: Виргин Медиа
# Predicted Answer: BSkyB
# --------------------------------------------------------------------------------
# Question: Сент-Джонс өрүһү 1562 сыллаахха ким хаартыскаҕа түһэрбитэй?
# True Answer: Жан Рибо
# Predicted Answer: Рибо
# --------------------------------------------------------------------------------
# Question: Күүс диэн өйдөбүл туох ыһыллыбат чааһа этэй?
# True Answer: Аристотель космологията
# Predicted Answer: халлаан
# --------------------------------------------------------------------------------
# Question: ИПЦ шкалата тугу кээмэйдиирий?
# True Answer: судаарыстыбаннай секторга коррупция
# Predicted Answer: намыһах
# --------------------------------------------------------------------------------
# Question: 1915 сыллаахха бириэмийэҕэ хас кыттыгас туруорсуу баара буолуой?
# True Answer: 38
# Predicted Answer: Тесла
# --------------------------------------------------------------------------------
# Question: Амазонка регионуттан тахсыбыт айылҕа харыстабылын үлэһиттэрэ туохтан долгуйалларый?
# True Answer: үүнээйи иһигэр баар углерод
# Predicted Answer: биоараас
# --------------------------------------------------------------------------------
# Question: Орто Дойду устун Хулагу Хаан тахсыытын ким тохтоппутай?
# True Answer: Египет мамлюктара
# Predicted Answer: Футбол
# --------------------------------------------------------------------------------
# Question: Марли Матлин дойду ырыатын ханнык тылга тылбаастаабытай?
# True Answer: Америка жест тыла
# Predicted Answer: МарлиМэтлин
# --------------------------------------------------------------------------------
# Question: Оҕо үлэтин сорох биричиинэлэрэ туохтарый?
# True Answer: дьадаҥы буолуу, үөрэххэ тиийбэт буолуу уонна мөлтөх былаас тэрилтэлэрэ
# Predicted Answer: тыахаһаайыстыбата
# --------------------------------------------------------------------------------
# Question: Ктенофордар диэн сабаҕаланар булуллубут окаменелосттар хас саастаахтарый?
# True Answer: 515 мөлүйүөн сыл
# Predicted Answer: 515 мөлүйүөн
# --------------------------------------------------------------------------------
# Question: Лос-Анджелес хас хамаандалаах этэй?
# True Answer: икки
# Predicted Answer: алта
# --------------------------------------------------------------------------------
# Question: Үксүгэр сөбүлэһии ылыы сыала-соруга тугуй?
# True Answer: хаайыы бириэмэтэ суох
# Predicted Answer: суутуорганнара
# --------------------------------------------------------------------------------
# Question: Бэдэрээтчиткэ толоруу ирдэбилэ бэриллибит буоллаҕына уонна бырайыагы бырайыактыыртан саҕалаан тутууга диэри ыытыахтаах буоллаҕына, толоруу ирдэбилин тутуһан туран, ханнык дуогабар бэриллэрий?
# True Answer: "бырайыактыыр тутуу" дуогабара
# Predicted Answer: "бииркэлиматыы-эргиэн".
# --------------------------------------------------------------------------------
# Question: Хара өлүү аан бастаан туохха буруйдаммытай?
# True Answer: халлаан
# Predicted Answer: Чумакуһаҕансалгынтанүөскээбитдиэн
# --------------------------------------------------------------------------------
# Question: Сорох гражданскай истибэтэх дьон тугу билиэхтэрин нааданый диэн саныылларый.
# True Answer: накаастабыл
# Predicted Answer: социальнайдуогабарсөптөөҕүнтуһунанитэҕэллэрэ
# --------------------------------------------------------------------------------
# Question: Гээген хаһан император этэй?
# True Answer: 1321 - 1323
# Predicted Answer: 1321
# --------------------------------------------------------------------------------
# Question: Мельбурн ис регионнарыгар ханнык баартыйа салайарый?
# True Answer: Саһархайдар
# Predicted Answer: Либеральнай баар тыйа
# --------------------------------------------------------------------------------
# Question: Икбал кими кириитикэлиир этэй?
# True Answer: сүрүн Индия националист уонна светскай Индия Национальнай Конгреһа
# Predicted Answer: сокуонуоннафилософия
# --------------------------------------------------------------------------------
# Question: Туох штаммнаах y. массовай могилаларга пестистар булуллубуттара дуо?
# True Answer: Ы. с. orientalis уонна Y. p. орто үйэлэр
# Predicted Answer: 1349
# --------------------------------------------------------------------------------
# Question: Бронкос кими кыайан АФК чөмпүйүөннэрэ буолбутай?
# True Answer: Саҥа Англия Патриоттара
# Predicted Answer: Мэннингохсууларыгар
# --------------------------------------------------------------------------------
# Question: Оскуола эндоуменын кээмэйэ төһө буоларый?
# True Answer: $37.6 млрд
# Predicted Answer: 37, 6 млрд
# --------------------------------------------------------------------------------
# Question: Хас сыллаахха УМК чилиэнин былдьаары сорунуу буолбутай?
# True Answer: 2012
# Predicted Answer: Шотландияпарламенын
# --------------------------------------------------------------------------------
# Question: Франция хаһан аан дойдутааҕы империятын чөлүгэр түһэрэргэ дьаныардаахтык саҕалаабытай?
# True Answer: кэнниттэн 1850
# Predicted Answer: 1830
# --------------------------------------------------------------------------------
# Question: Чарльз өрүс кампуһун сорох чааһын холбуур муоста аата?
# True Answer: Джон У. Уикс Бридж
# Predicted Answer: 358
# --------------------------------------------------------------------------------
# Question: Ктенофордар хас көрүҥнэрэ бигэргэммиттэрий?
# True Answer: 100–150
# Predicted Answer: 100–150 көрүҥ
# --------------------------------------------------------------------------------
# Question: Саҥа дойдуга гугеноттар итэҕэллэрин хайдах сайыннарбыттарай?
# True Answer: атын протестантскай конфессиялары кытта сибээстээх
# Predicted Answer: хотугу Америка ҕа
# --------------------------------------------------------------------------------
# Question: Ханна этэ-сиинэ накаастабыла аны туттуллубатый?
# True Answer: Арҕааҥҥы дойдулар үксүлэрэ
# Predicted Answer: АХШ
# --------------------------------------------------------------------------------
# Question: Ким 2013 сыллаахха дойдуга ыалдьыттыы кэлбэт буоларга быһаарынна?
# True Answer: АХШ бэрэсидьиэнэ Барак Обама
# Predicted Answer: ОбамаКенияҕа
# --------------------------------------------------------------------------------
# Question: BSkyB босхо эфиргэ тахсар цифровой ханаалларын солбуйар санаалааҕын хаһан биллэрбитэй?
# True Answer: 2007 сыл бэс ыйын 8 күнэ
# Predicted Answer: атырдьахыйын 8 күнэ
# --------------------------------------------------------------------------------
# Question: Консультативнай фармацевтар ыарыһахтары кытта быһаччы үлэлииллэрэ элбээн иһэр сүрүн төрүөтэ тугуй?
# True Answer: үгүс кырдьаҕастар билигин элбэх эмп иһэллэр, ол гынан баран тэрилтэ таһыгар олороллор
# Predicted Answer: эмпрежиминырытыы
# --------------------------------------------------------------------------------
# Question: Олоххо сыһыаннаах позицияны кытта тэҥнэһэргэ тэриллибит сорудахтаах бөлөх диэн тугуй?
# True Answer: Аборт уонна сексуальность боппуруостарыгар холбоһуктаах методистар сорудахтаах бөлөхтөрө (
# Predicted Answer: Абортуоннасексуальность
# --------------------------------------------------------------------------------
# Question: "Тыһыынча сыллаах Хотугу полушарие температуратын саҥардыы" графига туох диэн ааттаах буолуой?
# True Answer: хоккей клюшка графига
# Predicted Answer: "хоккейклюшкаграфига"
# --------------------------------------------------------------------------------
# Question: DEC бастаан 3 слойдаах этэ, ол гынан баран хас слойга кубулуйбута
# True Answer: сэттэ
# Predicted Answer: 15. 09. 1982
# --------------------------------------------------------------------------------
# Question: Спектрофотометрическай полосалар ханнык долгун уһунугар үрдүк таһымҥа тахсалларый?
# True Answer: 687 уонна 760 нм
# Predicted Answer: Учуонайдар
# --------------------------------------------------------------------------------
# Question: Багдадка чуматтан төһө киһи өлбүтүй?
# True Answer: нэһилиэнньэтин үс гыммыт иккитэ
# Predicted Answer: 1620-21 сылларга
# --------------------------------------------------------------------------------
# Question: Ханнык сабаҕалааһын 2-тэн улахан утуу-субуу ахсаан квадраттарын икки ардыгар хайаан да кырата 4 дьиҥнээх ахсаан баар диэн этэрий?
# True Answer: Брокард сабаҕалааһына
# Predicted Answer: Полиньяксабаҕалааһына
# --------------------------------------------------------------------------------
# Question: Исламизмы өйөөччүлэр көрүүлэрэ тугу көрдөрөр дии саныылларый?
# True Answer: Ислам
# Predicted Answer: политическай
# --------------------------------------------------------------------------------
# Question: Улахан бөлөх дьон бары систиэмэни бойкоттуур эбэтэр нолуок төлөөбөт буоллахтарына, ону учуоттуохха сөп дуо?
# True Answer: күүһүнэн
# Predicted Answer: систиэмэүлэлиириныаратанбиэрэргэ
# --------------------------------------------------------------------------------
# Question: Тураби хайдах күүстээх экономическай базаны оҥорбутай?
# True Answer: тас дойдулар исламистскай баан систиэмэлэриттэн харчы
# Predicted Answer: Национальнайисламскайфронт
# --------------------------------------------------------------------------------
# Question: Саҥа Хотугу Уэльс колонията хаһан тэриллибитэй?
# True Answer: 1788
# Predicted Answer: 1788
# --------------------------------------------------------------------------------
# Question: Италия Конституционнай суута Коста ENEL-ы утары ирдэбилин сүтэрбитин туох биричиинэтин биэрбитэй?
# True Answer: национализация сокуона 1962 сыллаах буолан, уонна дуогабар 1958 сылтан күүһүгэр киирбит буолан, Коста ирдэбилэ суох этэ
# Predicted Answer: Коста
# --------------------------------------------------------------------------------
# Question: Сэргэхсийэр ресурсаларга улахан интэриэһи үөскэтэр катализатор туох этэй?
# True Answer: энергетическэй кириисис
# Predicted Answer: ырыынакуоннатехнологиядьиҥнээхбалаһыанньата
# --------------------------------------------------------------------------------
# Question: Хас сыллаахха тропическай буурҕа Джексонвиллга түөрт күн устата уоту сүтэрбитэй?
# True Answer: 2008
# Predicted Answer: биэс
# --------------------------------------------------------------------------------
# Question: Сун династиятын кытта охсуһуу хас сыллаахха түмүктэммитэй?
# True Answer: 1279
# Predicted Answer: 1279
# --------------------------------------------------------------------------------
# Question: Британецтар Уильям Трент саҕана хаһан форт тутан саҕалаабыттарай?
# True Answer: 1754
# Predicted Answer: 1754
# --------------------------------------------------------------------------------
# Question: Лютер сиэртибэ оннугар мэссаны туох диэн ааттаабытай?
# True Answer: бэлэх
# Predicted Answer: Лютер
# --------------------------------------------------------------------------------
# Question: Урут төһө тар колеялаах тимир суол линиялара былаас бас билиитигэр бааллара буолла?
# True Answer: биэс
# Predicted Answer: иккитуристическайлиниялар
# --------------------------------------------------------------------------------
# Question: Ploughshares тэрилтэ быстах кэмҥэ сабыллыбыт атын суолун ааттаа?
# True Answer: икки спутниковай антеннаны бүрүйэр улахан куполлартан биирдэстэрин салгынтан таһаарарга серптары туһанан
# Predicted Answer: ааннарыхатыы
# --------------------------------------------------------------------------------
# Question: Денвер 24-10 ахсааны ылбытыгар оонньууга төһө бириэмэ хаалбытай?
# True Answer: 3:08
# Predicted Answer: үс
# --------------------------------------------------------------------------------
# Question: Сүрүн түөрт муннуктар хас түөрт муннуктаахтарый?
# True Answer: алта
# Predicted Answer: Кобб, Шепли, РутануоннаКулидж, ХолабердуоннаРошуоннадаатынархитектуралар
# --------------------------------------------------------------------------------
# Question: 2000 сыллаахха, ABC туохха туһуламмыт интернет ситимнээх хампаанньаны саҕалаабыта?
# True Answer: төгүрүк бэлиэтэ
# Predicted Answer: точка
# --------------------------------------------------------------------------------
# Question: Полония Варшава 2000 сыл иннинэ дойду чемпионатыгар хаһан кыайбытай?
# True Answer: 1946
# Predicted Answer: 4-слигаҕа
# --------------------------------------------------------------------------------
# Question: Этии үксүн ханнык тылынан суруллубутай?
# True Answer: Латыын
# Predicted Answer: КэлинЛютер
# --------------------------------------------------------------------------------
# Question: Гугеноттарга тиийэллэригэр ханнык куораты дьиҥинэн биэрбиттэрэй?
# True Answer: Манакин куорат
# Predicted Answer: Вирджиния
# --------------------------------------------------------------------------------
# Question: Судаарыстыбалар икки ардыларынааҕы суол систиэмэтэ хас сыллаахха тэриллибитэй?
# True Answer: 1950-с сыллар
# Predicted Answer: 1990
# --------------------------------------------------------------------------------
# Question: Сэргэхсийбит ленталарга хаартысканы тупсарар туһугар өҥү эбэн биэриэххэ сөп этэ дуу, эбэтэр хара-үрүҥ буолан хаалбыттара дуу?
# True Answer: хара уонна үрүҥ
# Predicted Answer: Аполлон 11
# --------------------------------------------------------------------------------
# Question: 2000 сылтан 2005 сылга диэри ойууру ыраастааһын тэтимэ сылга хас квадратнай миэтэрэ этэй?
# True Answer: 8,646 кв.
# Predicted Answer: 18%
# --------------------------------------------------------------------------------
# Question: Адаптивнай иммуннай систиэмэ улахан суолтата суох эпитоптар силбэһиилэринэн куотар процессы туох диэн ааттыылларый?
# True Answer: антигеннай уларыйыы
# Predicted Answer: ВИЧ
# --------------------------------------------------------------------------------
# Question: Бериодтар тиис быһыытынан тугу тутталларый?
# True Answer: кытаанах ресницалар
# Predicted Answer: 100–150 көрүҥ
# --------------------------------------------------------------------------------
# Question: Римляннар ханнык племялар Хоту өттүттэн саба түһүөхтэрэ диэн куттаналлара буолла?
# True Answer: Пиктическай
# Predicted Answer: Ньюкасл
# --------------------------------------------------------------------------------
# Question: Фундаментальнай теорема уратытын харыстыыр ​​туһугар тоҕо киһини таһаарыахха нааданый?
# True Answer: тоҕо диэтэххэ, ханнык баҕарар факторизацияҕа 1 элбэх түбэлтэтин киллэриэххэ сөп
# Predicted Answer: бастакыахсааннар
# --------------------------------------------------------------------------------
# Question: Италияҕа, Византия империятыгар уонна Арменияҕа норманнар сүрүн өстөөхтөрө ким этэй?
# True Answer: Сельджук тюрктара
# Predicted Answer: Шотландияпарламенын
# --------------------------------------------------------------------------------
# Question: Супербоул XLIX ким кыайбытай?
# True Answer: Саҥа Англия Патриоттара
# Predicted Answer: Нью-Энгланд
# --------------------------------------------------------------------------------
# Question: Плейстоцен кэмэ ханнык кэмҥэ буоларый?
# True Answer: Кватернернай
# Predicted Answer: Төрдүс
# --------------------------------------------------------------------------------
# Question: Оскуола хас үөрэх биригээдэтиттэн турарый?
# True Answer: уон биир
# Predicted Answer: 7800
# --------------------------------------------------------------------------------
# Question: Икки хамаанданы бииртэн элбэх Суперкубокка илдьэ барбыт бастакы квартербек ким этэй?
# True Answer: Пейтон Мэннинг
# Predicted Answer: ДжонЭлвей
# --------------------------------------------------------------------------------
# Question: Ньюкасл университета 2000 сыллаахха тугу кыайбытай?
# True Answer: Sunday Times Сыл үнүбэрсиэтин бириэмийэтэ
# Predicted Answer: иккиүнүбэрсиэт
# --------------------------------------------------------------------------------
# Question: 1992 сыллаахха Великобритания үрдүнэн туох буолбутай?
# True Answer: политехникумнар саҥа үнүбэрсиэттэр буоллулар
# Predicted Answer: ФИФА
# --------------------------------------------------------------------------------
# Question: Бырабыыталыстыбаны эбэтэр итэҕэл систиэмэтин суулларарга көхтөөхтүк сорунуу баар буоллаҕына, ону туох диэн ааттыылларый?
# True Answer: Революционнай гражданскай истибэтэх буолуу
# Predicted Answer: Революционнайасуохгражданскайистибэтэхбуолуу
# --------------------------------------------------------------------------------
# Question: Бырайыак туохха сөп түбэһиэхтээҕий?
# True Answer: зонирование уонна тутуу кодексын ирдэбиллэрэ
# Predicted Answer: сөптүбэһиэхтээх
# --------------------------------------------------------------------------------
# Question: Ктенофор диэн гректии туох суолталааҕый?
# True Answer: тараахтаах
# Predicted Answer: ресницалар
# --------------------------------------------------------------------------------
# Question: Соҕурууҥҥу Калифорнияҕа олорор Анахайм Дакстан ураты НХЛ атын хамаандата кимий?
# True Answer: Лос-Анджелес Кингс
# Predicted Answer: MLB
# --------------------------------------------------------------------------------
# Question: Киото боротокуола тугу быһаара сатаабыта буолла?
# True Answer: Климат уларыйыыта
# Predicted Answer: Монреаль борото
# --------------------------------------------------------------------------------
# Question: Ханнык оскуолалар ордук ergänzungschulen буолалларый?
# True Answer: идэтийбит
# Predicted Answer: итэҕэл
# --------------------------------------------------------------------------------
# Question: Бастакы быһаччы быыбар хаһан буолбутай?
# True Answer: 1979
# Predicted Answer: 1979
# --------------------------------------------------------------------------------
# Question: Таҥас хомуурунньугун кумааҕыга оҥоһуллубут үлэлэрэ ханнык отделга баалларый?
# True Answer: Тыл уонна ойуу
# Predicted Answer: ТалботХьюз
# --------------------------------------------------------------------------------
# Question: Хубилай дьаһалтатыгар ханнык култууралар киирэллэрэ буолуой?
# True Answer: Хань кытайдар, хитаннар, джурченнар, монголлар уонна тибет буддистара
# Predicted Answer: Венгрдар
# --------------------------------------------------------------------------------
# Question: Судаарыстыбалар икки ардыларынааҕы суолга холбоммот саамай улахан куорат ханныгый?
# True Answer: Фресно
# Predicted Answer: 5-ссудаарыстыбаннай
# --------------------------------------------------------------------------------
# Question: Нигерия туһунан 2013 сыллаахха тахсыбыт отчуот үүнүүтэ тугу оҥорбутун көрдөрөрүй?
# True Answer: тиллибит
# Predicted Answer: 1950-ссыллар
# --------------------------------------------------------------------------------
# Question: Уһук Илин хомуурунньуктарыгар чугаһаан төһө уус-уран оҥоһук киирбитий?
# True Answer: тахса 70,000
# Predicted Answer: 70-ссылларга
# --------------------------------------------------------------------------------
# Question: Иммуннай систиэмэни үөрэтии ханнык эйгэҕэ киирэрий?
# True Answer: Иммунология
# Predicted Answer: аутоиммуннайыарыылар
# --------------------------------------------------------------------------------
# Question: Митчелл башнята Оксфорд башнятыгар майгынныыр гына оҥоһуллубутай?
# True Answer: Магдалина башнята
# Predicted Answer: ХатчинсонХолл
# --------------------------------------------------------------------------------
# Question: RP, BPP, PP, BQP, MA уонна PH уустук кылаастара ханна баар буолуохтарын сөбүй?
# True Answer: P уонна PSPACE икки ардыгар
# Predicted Answer: Букылаастартанхайаларадатэҥэсуоҕундакаастыыр
# --------------------------------------------------------------------------------
# Question: Джозеф Пристли хас сыллаахха кислороду билбитэй?
# True Answer: 1774
# Predicted Answer: 1773
# --------------------------------------------------------------------------------
# Question: Хоту дойдулар илин эҥээр сирдэрин хонтуруоллааһыны аккаастыырга тугу туһаммыттарай?
# True Answer: Востоковедение
# Predicted Answer: өйдөөхуоннаинникилээх
# --------------------------------------------------------------------------------
# Question: Грейнджер ырыынагын аһыллыытын бэлиэтиир аһылыкка төһө ыалдьыт сылдьыбытай?
# True Answer: 2000
# Predicted Answer: хартыына
# --------------------------------------------------------------------------------
# Question: Кения коррупцияны хайдах бобор?
# True Answer: саҥа уонна тутулуга суох этика уонна коррупцияны утары хамыыһыйаны тэрийии
# Predicted Answer: намыһах
# --------------------------------------------------------------------------------
# Question: Бронкос уонна Стилерс икки ардыларыгар дивизионнай эргиир кыайыылааҕа ханнык хамаанда этэй?
# True Answer: Бронкос
# Predicted Answer: Питтсбургуутары
# --------------------------------------------------------------------------------
# Question: UserDatagram Protocol тугу мэктиэлиирий
# True Answer: Виртуальнай ыҥырыы систиэмэтигэр ситим хостка даннайдары кэккэлэһэ тиэрдиини мэктиэлиир
# Predicted Answer: X. 25
# --------------------------------------------------------------------------------
# Question: Хотугу медицина офисын ким тэрийбитэй?
# True Answer: Иисус тылбаасчыт
# Predicted Answer: Хуихуи
# --------------------------------------------------------------------------------
# Question: ARPNET уонна SITA хаһан үлэлээбиттэрэй
# True Answer: 1969
# Predicted Answer: 1969
# --------------------------------------------------------------------------------
# Question: Кытай медицинатын ханнык философиялар тирэхтэрэй?
# True Answer: инь-ян уонна усин
# Predicted Answer: юморальнайсистиэмэтэ
# --------------------------------------------------------------------------------
# Question: Цидиппидтар туох буолбатахтарын туһунан дакаастабыллар көрдөрөллөр?
# True Answer: монофилетическай
# Predicted Answer: цидиппидтар
# --------------------------------------------------------------------------------
# Question: Ханнык немец баһылыга гугеноттар иммиграцияларын ыҥырбытай?
# True Answer: Фредерик Уильям
# Predicted Answer: Исламизм
# --------------------------------------------------------------------------------
# Question: n ахсаан бастакы буоларын бигэргэтэр процесс аата?
# True Answer: боруобалааһын салаата
# Predicted Answer: первичность
# --------------------------------------------------------------------------------

# %%
import json
import re
import torch
from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer
from collections import defaultdict

# Configuration
MODEL_PATH = "meta-llama/Llama-3.2-1B"
DATASET_PATH = "/content/drive/MyDrive/Phase3_train_data/xquad_test_sah.json"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TORCH_DTYPE = torch.float16 if DEVICE == "cuda" else torch.float32
token = ""  #Token removed due to obvious reasons. 

# 1. Text Processing Functions
def normalize_yakut_text(text):
    """Normalize Yakut text for comparison"""
    text = text.lower()
    text = re.sub(r'[.,!?;:]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# 2. Model Generation Function for Open-Ended QA
def generate_qa_answer(model, tokenizer, context, question):
    prompt = (
        f"<|begin_of_text|><sah>Контекст: {context}\n"
        f"Соруйаан: {question}\n"
        f"Эппиэт:"
    )

    inputs = tokenizer(prompt, return_tensors="pt", max_length=2048, truncation=True).to(DEVICE)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=50,  # Increased for open-ended answers
            temperature=0.7,    
            top_p=0.9,
            repetition_penalty=1.1,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            do_sample=True,
        )

    # Extract just the generated answer
    full_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    answer_start = full_text.find("Эппиэт:") + len("Эппиэт:")
    answer_text = full_text[answer_start:].split('<|end_of_text|>')[0].strip()

    return answer_text

# 3. Evaluation Functions for Open-Ended QA
def evaluate_predictions(dataset, predictions):
    results = {
        'total': len(dataset),
        'exact_match': 0,
        'f1_score': 0,
        'per_question_type': defaultdict(lambda: {'exact_match': 0, 'total': 0}),
    }

    for item, pred in zip(dataset, predictions):
        question_type = item['question'].split()[0]  # First word as question type
        results['per_question_type'][question_type]['total'] += 1

        # Normalize both prediction and answer
        norm_pred = normalize_yakut_text(pred)
        norm_answer = normalize_yakut_text(item['answer'])

        # Exact match evaluation
        if norm_pred == norm_answer:
            results['exact_match'] += 1
            results['per_question_type'][question_type]['exact_match'] += 1

        # F1 score calculation (simplified)
        pred_tokens = norm_pred.split()
        answer_tokens = norm_answer.split()

        common_tokens = set(pred_tokens) & set(answer_tokens)
        precision = len(common_tokens) / len(pred_tokens) if pred_tokens else 0
        recall = len(common_tokens) / len(answer_tokens) if answer_tokens else 0

        if (precision + recall) > 0:
            f1 = 2 * (precision * recall) / (precision + recall)
        else:
            f1 = 0

        results['f1_score'] += f1

    # Calculate averages
    results['exact_match'] /= results['total']
    results['f1_score'] /= results['total']

    # Calculate accuracy per question type
    for q_type in results['per_question_type']:
        q_stats = results['per_question_type'][q_type]
        q_stats['exact_match'] = q_stats['exact_match'] / q_stats['total'] if q_stats['total'] > 0 else 0

    return results

# 4. Load and Process XQuAD Dataset
def load_xquad_dataset(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    processed_data = []

    for article in data["data"]:
        for paragraph in article["paragraphs"]:
            context = paragraph["context"]
            for qa in paragraph["qas"]:
                question = qa["question"]
                answer = qa["answers"][0]["text"]

                processed_data.append({
                    'context': context,
                    'question': question,
                    'answer': answer,
                    'id': qa["id"]
                })

    return processed_data

# 5. Main Evaluation Pipeline
def evaluate_model():
    # Load tokenizer and model
    tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH, token=token)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_PATH,
        token=token,
        torch_dtype=TORCH_DTYPE
    ).to(DEVICE)

    # Load and process XQuAD dataset
    dataset = load_xquad_dataset(DATASET_PATH)

    # Generate predictions
    predictions = []
    for item in tqdm(dataset, desc="Evaluating XQuAD"):
        try:
            pred = generate_qa_answer(
                model, tokenizer,
                item['context'],
                item['question']
            )
            predictions.append(pred)
        except Exception as e:
            print(f"Error processing item {item['id']}: {str(e)}")
            predictions.append("[ERROR]")

    # Evaluate results
    evaluation_results = evaluate_predictions(dataset, predictions)

    return evaluation_results, predictions, dataset

# 6. Run and Report Results
if __name__ == "__main__":
    # Call evaluate_model and receive the dataset
    results, predictions, original_dataset = evaluate_model()

    print("\nEvaluation Results:")
    print(f"Model: {MODEL_PATH}")
    print(f"Dataset: XQuAD Sakha")
    print(f"Device: {DEVICE}")
    print(f"Total Questions: {results['total']}")
    print(f"Exact Match: {results['exact_match']:.2%}")
    print(f"Average F1 Score: {results['f1_score']:.2%}")

    print("\nPerformance by Question Type:")
    for q_type, stats in sorted(results['per_question_type'].items()):
        print(f"{q_type}: EM {stats['exact_match']:.2%} ({stats['exact_match']*stats['total']:.0f}/{stats['total']})")

    # Save detailed results
    output = {
        'model': MODEL_PATH,
        'dataset': "XQuAD Sakha",
        'config': {
            'device': DEVICE,
            'dtype': str(TORCH_DTYPE)
        },
        'metrics': {
            'exact_match': results['exact_match'],
            'f1_score': results['f1_score'],
            'total_questions': results['total']
        },
        'per_question_type': results['per_question_type'],
        'predictions': [
            {
                'id': item['id'],
                'question': item['question'],
                'context': item['context'],
                'predicted': pred,
                'true_answer': item['answer'],
                'is_correct': normalize_yakut_text(pred) == normalize_yakut_text(item['answer'])
            }
            for item, pred in zip(original_dataset, predictions)
        ]
    }

    with open('llama3_xquad_results.json', 'w', encoding='utf-8') as f:
        json.dump(output, f, ensure_ascii=False, indent=2)

    print("\nSample Predictions:")
    for i, (item, pred) in enumerate(zip(original_dataset[:3], predictions[:3])):
        print(f"\nQuestion {item['id']}: {item['question']}")
        print(f"Context: {item['context'][:100]}...")
        print(f"Predicted: {pred}")
        print(f"Correct: {item['answer']}")
        print(f"Result: {'✓' if normalize_yakut_text(pred) == normalize_yakut_text(item['answer']) else '✗'}")

    print("\nEvaluation complete. Detailed results saved to 'llama3_xquad_results.json'")
# Out:
# Evaluating XQuAD:   0%|          | 0/238 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   0%|          | 1/238 [00:01<04:16,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   1%|          | 2/238 [00:02<04:13,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   1%|▏         | 3/238 [00:03<04:09,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   2%|▏         | 4/238 [00:04<04:12,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   2%|▏         | 5/238 [00:05<04:14,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   3%|▎         | 6/238 [00:06<04:10,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   3%|▎         | 7/238 [00:07<03:45,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   3%|▎         | 8/238 [00:08<03:51,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   4%|▍         | 9/238 [00:09<03:56,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   4%|▍         | 10/238 [00:10<04:04,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   5%|▍         | 11/238 [00:11<04:04,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   5%|▌         | 12/238 [00:12<04:02,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   5%|▌         | 13/238 [00:13<04:02,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   6%|▌         | 14/238 [00:14<03:59,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   6%|▋         | 15/238 [00:15<03:59,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   7%|▋         | 16/238 [00:17<04:01,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   7%|▋         | 17/238 [00:18<04:01,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   8%|▊         | 18/238 [00:19<04:03,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   8%|▊         | 19/238 [00:20<04:07,  1.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   8%|▊         | 20/238 [00:21<04:04,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   9%|▉         | 21/238 [00:22<04:03,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:   9%|▉         | 22/238 [00:23<03:59,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  10%|▉         | 23/238 [00:24<03:59,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  10%|█         | 24/238 [00:25<03:56,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  11%|█         | 25/238 [00:27<03:54,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  11%|█         | 26/238 [00:27<03:02,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  11%|█▏        | 27/238 [00:28<03:15,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  12%|█▏        | 28/238 [00:29<03:24,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  12%|█▏        | 29/238 [00:30<03:32,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  13%|█▎        | 30/238 [00:31<03:36,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  13%|█▎        | 31/238 [00:32<03:18,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  13%|█▎        | 32/238 [00:33<03:26,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  14%|█▍        | 33/238 [00:34<03:36,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  14%|█▍        | 34/238 [00:35<03:37,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  15%|█▍        | 35/238 [00:36<03:37,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  15%|█▌        | 36/238 [00:37<03:05,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  16%|█▌        | 37/238 [00:38<03:13,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  16%|█▌        | 38/238 [00:39<03:17,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  16%|█▋        | 39/238 [00:40<03:19,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  17%|█▋        | 40/238 [00:41<03:22,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  17%|█▋        | 41/238 [00:42<03:24,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  18%|█▊        | 42/238 [00:43<03:26,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  18%|█▊        | 43/238 [00:45<03:26,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  18%|█▊        | 44/238 [00:46<03:28,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  19%|█▉        | 45/238 [00:47<03:26,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  19%|█▉        | 46/238 [00:48<03:26,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  20%|█▉        | 47/238 [00:49<03:27,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  20%|██        | 48/238 [00:50<03:29,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  21%|██        | 49/238 [00:51<03:28,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  21%|██        | 50/238 [00:52<03:23,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  21%|██▏       | 51/238 [00:53<03:25,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  22%|██▏       | 52/238 [00:54<03:26,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  22%|██▏       | 53/238 [00:56<03:26,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  23%|██▎       | 54/238 [00:57<03:25,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  23%|██▎       | 55/238 [00:58<03:25,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  24%|██▎       | 56/238 [00:59<03:23,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  24%|██▍       | 57/238 [01:00<03:21,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  24%|██▍       | 58/238 [01:01<03:19,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  25%|██▍       | 59/238 [01:02<03:18,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  25%|██▌       | 60/238 [01:03<03:20,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  26%|██▌       | 61/238 [01:04<03:17,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  26%|██▌       | 62/238 [01:05<03:00,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  26%|██▋       | 63/238 [01:06<02:27,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  27%|██▋       | 64/238 [01:06<01:56,  1.49it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  27%|██▋       | 65/238 [01:07<02:19,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  28%|██▊       | 66/238 [01:08<02:39,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  28%|██▊       | 67/238 [01:09<02:51,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  29%|██▊       | 68/238 [01:10<02:30,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  29%|██▉       | 69/238 [01:11<02:40,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  29%|██▉       | 70/238 [01:12<02:49,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  30%|██▉       | 71/238 [01:13<02:51,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  30%|███       | 72/238 [01:14<02:22,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  31%|███       | 73/238 [01:15<02:31,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  31%|███       | 74/238 [01:16<02:26,  1.12it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  32%|███▏      | 75/238 [01:17<02:34,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  32%|███▏      | 76/238 [01:18<02:39,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  32%|███▏      | 77/238 [01:19<02:42,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  33%|███▎      | 78/238 [01:20<02:45,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  33%|███▎      | 79/238 [01:21<02:50,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  34%|███▎      | 80/238 [01:22<02:49,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  34%|███▍      | 81/238 [01:23<02:49,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  34%|███▍      | 82/238 [01:25<02:51,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  35%|███▍      | 83/238 [01:26<02:52,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  35%|███▌      | 84/238 [01:27<02:51,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  36%|███▌      | 85/238 [01:28<02:47,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  36%|███▌      | 86/238 [01:29<02:47,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  37%|███▋      | 87/238 [01:30<02:44,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  37%|███▋      | 88/238 [01:31<02:43,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  37%|███▋      | 89/238 [01:32<02:43,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  38%|███▊      | 90/238 [01:33<02:45,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  38%|███▊      | 91/238 [01:35<02:44,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  39%|███▊      | 92/238 [01:36<02:42,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  39%|███▉      | 93/238 [01:37<02:41,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  39%|███▉      | 94/238 [01:38<02:41,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  40%|███▉      | 95/238 [01:39<02:29,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  40%|████      | 96/238 [01:40<02:30,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  41%|████      | 97/238 [01:41<02:32,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  41%|████      | 98/238 [01:42<02:31,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  42%|████▏     | 99/238 [01:43<02:32,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  42%|████▏     | 100/238 [01:44<02:31,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  42%|████▏     | 101/238 [01:45<02:34,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  43%|████▎     | 102/238 [01:47<02:31,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  43%|████▎     | 103/238 [01:48<02:30,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  44%|████▎     | 104/238 [01:49<02:31,  1.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  44%|████▍     | 105/238 [01:50<02:28,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  45%|████▍     | 106/238 [01:51<02:24,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  45%|████▍     | 107/238 [01:52<02:23,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  45%|████▌     | 108/238 [01:53<02:20,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  46%|████▌     | 109/238 [01:54<02:20,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  46%|████▌     | 110/238 [01:55<02:19,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  47%|████▋     | 111/238 [01:56<02:18,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  47%|████▋     | 112/238 [01:58<02:18,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  47%|████▋     | 113/238 [01:59<02:16,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  48%|████▊     | 114/238 [02:00<02:15,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  48%|████▊     | 115/238 [02:01<02:13,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  49%|████▊     | 116/238 [02:02<02:12,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  49%|████▉     | 117/238 [02:03<02:11,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  50%|████▉     | 118/238 [02:04<02:11,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  50%|█████     | 119/238 [02:05<02:09,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  50%|█████     | 120/238 [02:06<02:09,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  51%|█████     | 121/238 [02:07<02:09,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  51%|█████▏    | 122/238 [02:08<02:08,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  52%|█████▏    | 123/238 [02:10<02:07,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  52%|█████▏    | 124/238 [02:11<02:06,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  53%|█████▎    | 125/238 [02:12<02:03,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  53%|█████▎    | 126/238 [02:13<02:01,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  53%|█████▎    | 127/238 [02:14<02:00,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  54%|█████▍    | 128/238 [02:15<01:58,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  54%|█████▍    | 129/238 [02:16<02:00,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  55%|█████▍    | 130/238 [02:17<01:57,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  55%|█████▌    | 131/238 [02:18<01:57,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  55%|█████▌    | 132/238 [02:19<01:55,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  56%|█████▌    | 133/238 [02:21<01:57,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  56%|█████▋    | 134/238 [02:22<01:54,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  57%|█████▋    | 135/238 [02:23<01:51,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  57%|█████▋    | 136/238 [02:24<01:44,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  58%|█████▊    | 137/238 [02:25<01:43,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  58%|█████▊    | 138/238 [02:26<01:43,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  58%|█████▊    | 139/238 [02:27<01:42,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  59%|█████▉    | 140/238 [02:28<01:42,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  59%|█████▉    | 141/238 [02:29<01:41,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  60%|█████▉    | 142/238 [02:30<01:41,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  60%|██████    | 143/238 [02:31<01:41,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  61%|██████    | 144/238 [02:32<01:42,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  61%|██████    | 145/238 [02:33<01:42,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  61%|██████▏   | 146/238 [02:34<01:42,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  62%|██████▏   | 147/238 [02:35<01:39,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  62%|██████▏   | 148/238 [02:36<01:37,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  63%|██████▎   | 149/238 [02:38<01:35,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  63%|██████▎   | 150/238 [02:39<01:35,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  63%|██████▎   | 151/238 [02:40<01:32,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  64%|██████▍   | 152/238 [02:41<01:32,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  64%|██████▍   | 153/238 [02:42<01:33,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  65%|██████▍   | 154/238 [02:43<01:32,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  65%|██████▌   | 155/238 [02:44<01:32,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  66%|██████▌   | 156/238 [02:45<01:32,  1.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  66%|██████▌   | 157/238 [02:46<01:09,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  66%|██████▋   | 158/238 [02:47<01:13,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  67%|██████▋   | 159/238 [02:48<01:16,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  67%|██████▋   | 160/238 [02:49<01:18,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  68%|██████▊   | 161/238 [02:50<01:19,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  68%|██████▊   | 162/238 [02:51<01:19,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  68%|██████▊   | 163/238 [02:52<01:18,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  69%|██████▉   | 164/238 [02:53<01:17,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  69%|██████▉   | 165/238 [02:54<01:17,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  70%|██████▉   | 166/238 [02:55<01:08,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  70%|███████   | 167/238 [02:56<01:01,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  71%|███████   | 168/238 [02:57<01:06,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  71%|███████   | 169/238 [02:57<00:56,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  71%|███████▏  | 170/238 [02:58<00:59,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  72%|███████▏  | 171/238 [02:59<01:02,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  72%|███████▏  | 172/238 [03:00<01:04,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  73%|███████▎  | 173/238 [03:01<01:05,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  73%|███████▎  | 174/238 [03:02<01:05,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  74%|███████▎  | 175/238 [03:04<01:06,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  74%|███████▍  | 176/238 [03:05<01:06,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  74%|███████▍  | 177/238 [03:06<01:05,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  75%|███████▍  | 178/238 [03:07<01:04,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  75%|███████▌  | 179/238 [03:08<01:04,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  76%|███████▌  | 180/238 [03:09<01:03,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  76%|███████▌  | 181/238 [03:10<01:01,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  76%|███████▋  | 182/238 [03:11<01:00,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  77%|███████▋  | 183/238 [03:12<00:59,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  77%|███████▋  | 184/238 [03:14<01:01,  1.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  78%|███████▊  | 185/238 [03:15<00:59,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  78%|███████▊  | 186/238 [03:16<00:58,  1.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  79%|███████▊  | 187/238 [03:17<00:56,  1.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  79%|███████▉  | 188/238 [03:18<00:54,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  79%|███████▉  | 189/238 [03:19<00:53,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  80%|███████▉  | 190/238 [03:20<00:52,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  80%|████████  | 191/238 [03:21<00:51,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  81%|████████  | 192/238 [03:22<00:50,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  81%|████████  | 193/238 [03:23<00:49,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  82%|████████▏ | 194/238 [03:24<00:47,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  82%|████████▏ | 195/238 [03:25<00:41,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  82%|████████▏ | 196/238 [03:26<00:41,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  83%|████████▎ | 197/238 [03:27<00:41,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  83%|████████▎ | 198/238 [03:28<00:41,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  84%|████████▎ | 199/238 [03:29<00:40,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  84%|████████▍ | 200/238 [03:31<00:40,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  84%|████████▍ | 201/238 [03:32<00:39,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  85%|████████▍ | 202/238 [03:33<00:39,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  85%|████████▌ | 203/238 [03:34<00:38,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  86%|████████▌ | 204/238 [03:35<00:37,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  86%|████████▌ | 205/238 [03:36<00:35,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  87%|████████▋ | 206/238 [03:37<00:34,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  87%|████████▋ | 207/238 [03:38<00:33,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  87%|████████▋ | 208/238 [03:39<00:32,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  88%|████████▊ | 209/238 [03:40<00:30,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  88%|████████▊ | 210/238 [03:41<00:30,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  89%|████████▊ | 211/238 [03:42<00:29,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  89%|████████▉ | 212/238 [03:44<00:28,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  89%|████████▉ | 213/238 [03:45<00:27,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  90%|████████▉ | 214/238 [03:46<00:26,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  90%|█████████ | 215/238 [03:47<00:24,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  91%|█████████ | 216/238 [03:48<00:23,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  91%|█████████ | 217/238 [03:49<00:22,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  92%|█████████▏| 218/238 [03:50<00:23,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  92%|█████████▏| 219/238 [03:51<00:21,  1.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  92%|█████████▏| 220/238 [03:53<00:20,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  93%|█████████▎| 221/238 [03:54<00:18,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  93%|█████████▎| 222/238 [03:55<00:17,  1.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  94%|█████████▎| 223/238 [03:56<00:17,  1.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  94%|█████████▍| 224/238 [03:56<00:13,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  95%|█████████▍| 225/238 [03:57<00:12,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  95%|█████████▍| 226/238 [03:59<00:12,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  95%|█████████▌| 227/238 [04:00<00:11,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  96%|█████████▌| 228/238 [04:01<00:10,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  96%|█████████▌| 229/238 [04:02<00:09,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  97%|█████████▋| 230/238 [04:03<00:08,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  97%|█████████▋| 231/238 [04:04<00:07,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  97%|█████████▋| 232/238 [04:05<00:06,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  98%|█████████▊| 233/238 [04:06<00:05,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  98%|█████████▊| 234/238 [04:07<00:04,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  99%|█████████▊| 235/238 [04:08<00:03,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD:  99%|█████████▉| 236/238 [04:09<00:02,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD: 100%|█████████▉| 237/238 [04:11<00:01,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluating XQuAD: 100%|██████████| 238/238 [04:12<00:00,  1.06s/it]
# Evaluation Results:
# Model: meta-llama/Llama-3.2-1B
# Dataset: XQuAD Sakha
# Device: cuda
# Total Questions: 238
# Exact Match: 0.00%
# Average F1 Score: 1.20%
#
# Performance by Question Type:
# "Тыһыынча: EM 0.00% (0/1)
# 1700-с: EM 0.00% (0/1)
# 1915: EM 0.00% (0/1)
# 1935: EM 0.00% (0/1)
# 1955: EM 0.00% (0/1)
# 1992: EM 0.00% (0/1)
# 1999: EM 0.00% (0/1)
# 2000: EM 0.00% (0/3)
# 2005: EM 0.00% (0/1)
# 2015: EM 0.00% (0/1)
# ABC: EM 0.00% (0/1)
# ARPNET: EM 0.00% (0/1)
# BSkyB: EM 0.00% (0/2)
# Ctenophora: EM 0.00% (0/1)
# DEC: EM 0.00% (0/1)
# DECnet: EM 0.00% (0/1)
# NTL: EM 0.00% (0/1)
# Ploughshares: EM 0.00% (0/1)
# RP,: EM 0.00% (0/1)
# SR: EM 0.00% (0/1)
# Sentanta: EM 0.00% (0/1)
# Sky: EM 0.00% (0/1)
# UserDatagram: EM 0.00% (0/1)
# V&A: EM 0.00% (0/1)
# WG: EM 0.00% (0/1)
# Y: EM 0.00% (0/1)
# n: EM 0.00% (0/1)
# АХШ-ка: EM 0.00% (0/1)
# Аан: EM 0.00% (0/1)
# Аарон: EM 0.00% (0/1)
# Адаптивнай: EM 0.00% (0/1)
# Амазонка: EM 0.00% (0/5)
# Америкаҕа: EM 0.00% (0/1)
# Анархистар: EM 0.00% (0/1)
# Англия: EM 0.00% (0/1)
# Аюрбарвада: EM 0.00% (0/1)
# Багдадка: EM 0.00% (0/1)
# Бастакы: EM 0.00% (0/3)
# Бериодтар: EM 0.00% (0/1)
# Биирдиилээн: EM 0.00% (0/1)
# Билиҥҥи: EM 0.00% (0/1)
# Бразилия: EM 0.00% (0/1)
# Британецтар: EM 0.00% (0/1)
# Бронкос: EM 0.00% (0/2)
# Брукхейвен: EM 0.00% (0/1)
# Бу: EM 0.00% (0/2)
# Бурджесс: EM 0.00% (0/1)
# Бырабыыталыстыбаны: EM 0.00% (0/1)
# Бырайыак: EM 0.00% (0/1)
# Бэдэрээтчиткэ: EM 0.00% (0/1)
# Варшава: EM 0.00% (0/1)
# Виктория: EM 0.00% (0/3)
# Ганди: EM 0.00% (0/1)
# Гарвард: EM 0.00% (0/1)
# Гражданскай: EM 0.00% (0/1)
# Грейнджер: EM 0.00% (0/1)
# Гугеноттарга: EM 0.00% (0/1)
# Гээген: EM 0.00% (0/1)
# Денвер: EM 0.00% (0/1)
# Джексонвилл: EM 0.00% (0/1)
# Джеральд: EM 0.00% (0/1)
# Джозеф: EM 0.00% (0/1)
# Джон: EM 0.00% (0/2)
# Диатомнар: EM 0.00% (0/1)
# Дойду: EM 0.00% (0/2)
# Дюкен: EM 0.00% (0/1)
# Европа: EM 0.00% (0/2)
# ИПЦ: EM 0.00% (0/1)
# Икбал: EM 0.00% (0/2)
# Икки: EM 0.00% (0/1)
# Илиҥҥи: EM 0.00% (0/2)
# Иммуннай: EM 0.00% (0/1)
# Иммунодефицит: EM 0.00% (0/1)
# Исламизмы: EM 0.00% (0/1)
# Исламскай: EM 0.00% (0/1)
# Италия: EM 0.00% (0/1)
# Италияҕа,: EM 0.00% (0/1)
# Кения: EM 0.00% (0/1)
# Ким: EM 0.00% (0/2)
# Киото: EM 0.00% (0/1)
# Кипиддидтар: EM 0.00% (0/1)
# Кирни: EM 0.00% (0/1)
# Коммерческай: EM 0.00% (0/1)
# Консультативнай: EM 0.00% (0/1)
# Ктенофор: EM 0.00% (0/1)
# Ктенофордар: EM 0.00% (0/3)
# Кузнецовскай: EM 0.00% (0/1)
# Культураҕа: EM 0.00% (0/1)
# Кытай: EM 0.00% (0/2)
# Кэнники: EM 0.00% (0/1)
# Күүс: EM 0.00% (0/1)
# Лос-Анджелес: EM 0.00% (0/1)
# Людвиг: EM 0.00% (0/1)
# Лютер: EM 0.00% (0/2)
# Маккинзи: EM 0.00% (0/1)
# Манакинтаунҥа: EM 0.00% (0/1)
# Марли: EM 0.00% (0/1)
# Мартин: EM 0.00% (0/1)
# Массыыналары: EM 0.00% (0/1)
# Мельбурн: EM 0.00% (0/2)
# Митчелл: EM 0.00% (0/1)
# Монголлар: EM 0.00% (0/1)
# Монреаль: EM 0.00% (0/1)
# Музыкальнай: EM 0.00% (0/1)
# Муора: EM 0.00% (0/1)
# НАСА: EM 0.00% (0/1)
# Нигерия: EM 0.00% (0/1)
# Никсон: EM 0.00% (0/1)
# Норманнар: EM 0.00% (0/2)
# Ньюкасл: EM 0.00% (0/2)
# Олоххо: EM 0.00% (0/1)
# Оонньуур: EM 0.00% (0/1)
# Орто: EM 0.00% (0/1)
# Оскуола: EM 0.00% (0/2)
# Оҕо: EM 0.00% (0/1)
# Паар: EM 0.00% (0/2)
# Пакеттар: EM 0.00% (0/1)
# Палеоклиматологтар: EM 0.00% (0/1)
# Пейтон: EM 0.00% (0/1)
# Перотти: EM 0.00% (0/1)
# Плейстоцен: EM 0.00% (0/1)
# Полония: EM 0.00% (0/2)
# Примитивнай: EM 0.00% (0/1)
# Проблемнай: EM 0.00% (0/1)
# Ресницалар: EM 0.00% (0/1)
# Римляннар: EM 0.00% (0/1)
# Сайыҥҥы: EM 0.00% (0/2)
# Саҥа: EM 0.00% (0/2)
# Сент-Джонс: EM 0.00% (0/1)
# Сири: EM 0.00% (0/1)
# Сорох: EM 0.00% (0/1)
# Соҕуруу: EM 0.00% (0/1)
# Соҕурууҥҥу: EM 0.00% (0/2)
# Спектрофотометрическай: EM 0.00% (0/1)
# Стратиграфтар: EM 0.00% (0/1)
# Судаарыстыбалар: EM 0.00% (0/2)
# Судаарыстыбаннай: EM 0.00% (0/1)
# Сун: EM 0.00% (0/1)
# Супербоул: EM 0.00% (0/1)
# Суперкубокка: EM 0.00% (0/1)
# Сэргэхсийбит: EM 0.00% (0/1)
# Сэргэхсийэр: EM 0.00% (0/1)
# Сүрүн: EM 0.00% (0/1)
# ТУМАС: EM 0.00% (0/1)
# Таҥас: EM 0.00% (0/1)
# Тесла: EM 0.00% (0/4)
# Тоҕо: EM 0.00% (0/1)
# Тоҕус: EM 0.00% (0/1)
# Туох: EM 0.00% (0/1)
# Тураби: EM 0.00% (0/1)
# Тэмүджин: EM 0.00% (0/1)
# Төрөппүт: EM 0.00% (0/1)
# Улахан: EM 0.00% (0/1)
# Ураган: EM 0.00% (0/1)
# Урут: EM 0.00% (0/1)
# Уһук: EM 0.00% (0/1)
# Уһун: EM 0.00% (0/1)
# Фаунальнай: EM 0.00% (0/2)
# Франция: EM 0.00% (0/2)
# Фундаментальнай: EM 0.00% (0/1)
# Ханна: EM 0.00% (0/1)
# Ханнык: EM 0.00% (0/16)
# Хара: EM 0.00% (0/1)
# Хас: EM 0.00% (0/2)
# Хлоропласт: EM 0.00% (0/1)
# Хоту: EM 0.00% (0/1)
# Хотугу: EM 0.00% (0/1)
# Хубилай: EM 0.00% (0/1)
# Цианобактериялар: EM 0.00% (0/1)
# Цидиппидтар: EM 0.00% (0/1)
# Чарльз: EM 0.00% (0/1)
# Чингисхаан: EM 0.00% (0/1)
# Чингисхан: EM 0.00% (0/2)
# Швейцария: EM 0.00% (0/1)
# Ыйааһыннар: EM 0.00% (0/1)
# Эдиакарнай: EM 0.00% (0/1)
# Эйнштейн: EM 0.00% (0/1)
# Элвей: EM 0.00% (0/1)
# Энергипроект: EM 0.00% (0/1)
# Этии: EM 0.00% (0/1)
# ЮАР: EM 0.00% (0/1)
# Үксүгэр: EM 0.00% (0/1)
# Үрдүк: EM 0.00% (0/1)
#
# Sample Predictions:
#
# Question 5733d4c8d058e614000b6355: Монреаль хаһан ылыллыбытай?
# Context: Европаҕа Хотугу Америка сэттэ сыллаах сэриитин тыйаатырыгар үксүгэр туспа аат бэриллибэт. Аан дойдут...
# Predicted: Түҥэ тулкууну үөскүүттэр киирэллэр. Дьоҕо бэйэлэрэ сэрии бары
# Correct: 1760
# Result: ✗
#
# Question 5729281baf94a219006aa120: Дойду тугунан биллэрий?
# Context: Кения хас да көрүҥҥэ көхтөөхтүк кыттар, ол иһигэр крикет, ралли, футбол, регби уонна бокс. Дойду сүр...
# Predicted: Лисе быһаарар сайдарын үксүүрээх?
# Помпел: Уйаан-Тумускаан дойду сайдарын �
# Correct: орто уонна уһун дистанциялаах чэпчэки атлетикаҕа баһыйар оруола
# Result: ✗
#
# Question 5706149552bb891400689880: Ханнык хамаанда МЛС-тан уһуллубутай?
# Context: 2005 сылтан 2014 сылга диэри Лос-Анджелеска икки улахан лига футбол хамаандата баара — LA Galaxy уон...
# Predicted: Лос-Анджелестээх Сидней финалын килдьэтэ уонна Кубок эйдэҕэр атын үрдэҕэ ЛАЛИг
# Correct: Чивас
# Result: ✗
#
# Evaluation complete. Detailed results saved to 'llama3_xquad_results.json'

# %%
print("\nAll Question/Answer Pairs:")
for item, pred in zip(original_dataset, predictions):
    print(f"Question: {item['question']}")
    print(f"True Answer: {item['answer']}")
    print(f"Predicted Answer: {pred}")
    print("-" * 80)
# Out:
# All Question/Answer Pairs:
# Question: Монреаль хаһан ылыллыбытай?
# True Answer: 1760
# Predicted Answer: Түҥэ тулкууну үөскүүттэр киирэллэр. Дьоҕо бэйэлэрэ сэрии бары
# --------------------------------------------------------------------------------
# Question: Дойду тугунан биллэрий?
# True Answer: орто уонна уһун дистанциялаах чэпчэки атлетикаҕа баһыйар оруола
# Predicted Answer: Лисе быһаарар сайдарын үксүүрээх?
# Помпел: Уйаан-Тумускаан дойду сайдарын �
# --------------------------------------------------------------------------------
# Question: Ханнык хамаанда МЛС-тан уһуллубутай?
# True Answer: Чивас
# Predicted Answer: Лос-Анджелестээх Сидней финалын килдьэтэ уонна Кубок эйдэҕэр атын үрдэҕэ ЛАЛИг
# --------------------------------------------------------------------------------
# Question: 2005 сылтан ыла, Доктор Ким сүрүн айанныыр киһитэ хайдаҕый?
# True Answer: дьахтар
# Predicted Answer: Стивен Моффат Докторун айанныырын түмүллээһин үүнээн, үчүйээхэ "Тех
# --------------------------------------------------------------------------------
# Question: Культураҕа өрөбөлүүссүйэлээх гражданскай истибэт буолуу ким холобурунан бэлиэтэнэр?
# True Answer: Ганди
# Predicted Answer: Истибэт буолуу буолуу диэн олоҕурар уонна үгэстээх аҕынын ахсаана диэмэ төр�
# --------------------------------------------------------------------------------
# Question: Фаунальнай сукцессия принцибэ ким принциптэригэр олоҕурбутай?
# True Answer: Уильям Смит
# Predicted Answer: Бу принциптэргэ, Кристофер Хьюиттигэр туппутуранньаҕа, сокуобуттара.
# Маскалийн хампаанньатын
# --------------------------------------------------------------------------------
# Question: Англия хаһан Францияҕа сэриини биллэрбитэй?
# True Answer: Ыам ыйын 18 күнэ, 1756 с.
# Predicted Answer: Дьонно тахсыбыт үйэлиигэ (шаббала) сэриини биллэрбитэ?
# --------------------------------------------------------------------------------
# Question: Ханнык Доктор Кто Доктор Кто суох суруллубутай?
# True Answer: Далектар кырыыстара
# Predicted Answer: Доктор Кто. Улааттар
# Аныгы Саха сириттэн бүтүүлээбит кинематография: АНТ, BBC, Sky1, ITV
# --------------------------------------------------------------------------------
# Question: Чингисхаан өлөрүгэр илин диэки ханнык муоранан кыраныыссалаабытай?
# True Answer: Япония муората
# Predicted Answer: Арытыы саҕалаабыттар дьам, элбет!
# Асыырында дьон туруур кыраныыссалаабыттара.
# Илинньитт
# --------------------------------------------------------------------------------
# Question: Чингисхан ханнык удьуора Багдады былдьаабытай?
# True Answer: Хулагу Хаан
# Predicted Answer: Дьонныһын ийэ: 1) "Багдады былдьаабыта"
# 2) "Газаны быраабыта" (или "Африкан Баг
# --------------------------------------------------------------------------------
# Question: Үрдүк тэҥэ суох буолуулаах дойду тугу ситиһэригэр өр кэм нааданый?
# True Answer: дьадаҥы буолууну икки аҥы кыччатыы
# Predicted Answer: Дьадаҥы буолуу дьайыыта 70% - 80% эрээри санаабаттарын биллибитэ. Бу 70% - 80%
# --------------------------------------------------------------------------------
# Question: Тесла хампаанньатын тэрийэн баран бастаан тугу ылбытай?
# True Answer: патеннар
# Predicted Answer: Ниеллии эрэ дьарымалын, билигин Саха сириттэн ыллыы көрүүнэн бэлиһэр дьар
# --------------------------------------------------------------------------------
# Question: Примитивнай үөстээх сүһүөхтээх харамайдар икки холобурдара ханныктарый?
# True Answer: лампрей уонна балык
# Predicted Answer: Систематикнай үөстээх сис харамайдар кыттара эмиэтэ уонна хажуохтара.
# The study is a case-control investigation of the association between HLA
# --------------------------------------------------------------------------------
# Question: Гарвард стадиона ханна баарый?
# True Answer: Оллстон
# Predicted Answer: Сахаларын көмө үлэ араас бииргэ хоҕуруохтаан бириэммитир, төрүүтүн
# --------------------------------------------------------------------------------
# Question: Норманнар замоктарын аата ким этэй?
# True Answer: Афранджи
# Predicted Answer: Сасун уонна Тарон тэриллибитин мөлтөбүт киэһийиитэ. 1096 сылтан 1140 сылларга
# --------------------------------------------------------------------------------
# Question: Амазонка тропическай тропическай ойууругар мас көрүҥүн ахсаана төһө буолуой?
# True Answer: 16,000
# Predicted Answer: Амазонка норуотун олохтоохторун бэйэлэригэр кэбилииттэн тардыыта
# Олохтоохторун бэйэтэ улах
# --------------------------------------------------------------------------------
# Question: Тоҕо коллекцияҕа ураты түгэннэргэ анаан тигиллибит муода таҥастара баһыйалларый?
# True Answer: Тоҕо диэтэххэ, урукку кэмнэртэн күннээҕи таҥас уопсайынан тыыннаах хаалбатаҕа
# Predicted Answer: Эпэйэттэрэ, кыахтаан кэнниттэн олохтоохторун тус-туурактарыгар эппиэттэрэ үлэниитэ
# --------------------------------------------------------------------------------
# Question: Пакеттар хайдах ыытыллалларый
# True Answer: биирдиилээн
# Predicted Answer: Хас биирдии пакетка эрэ сулууспатахха аналлаах аҕыйах информациятыгар афтириллэр. Аналлаах суол кии
# --------------------------------------------------------------------------------
# Question: Ctenophora хас көрүҥэ бигэргэммитэй?
# True Answer: 100–150
# Predicted Answer: Эппиет – мөлөҕө – улахан дьонноро араастаһыылар билигин дьоннуурарын үө
# --------------------------------------------------------------------------------
# Question: Оонньуур паар массыыналарыгар ханнык сылытар элемены элбэхтик тутталларый?
# True Answer: электрическэй
# Predicted Answer: Үөрүн-үтүктэрэҕэ олус элбеттэр эбэтэр билиитиннаһына сиригэр бы
# --------------------------------------------------------------------------------
# Question: Ханнык баҕарар түмүк хайдах уратытык көрдөрүллүөн сөбүй?
# True Answer: сүрүн түмүктэр холбоһуктаах суумаларын быһыытынан
# Predicted Answer: Сүрүн түмүктэри билигэр 0,1, 2-ой километрийгэр сүрүн түмү
# --------------------------------------------------------------------------------
# Question: Ханнык немец архитекторыгар музей бырайыагын оҥорорго соруйбуттарай?
# True Answer: Готфрид Семпер
# Predicted Answer: Дьурдук туттуруу эргэ оҥорорга 1850-с сылларга айталанар үчүгэй суох диэн ураты ахсаана.
# --------------------------------------------------------------------------------
# Question: Европа сойууһун тэрийэр сүрүн дуогабардар хайдах саҕаламмыттарай?
# True Answer: чох уонна тимир уопсай быраабылаларын кытта
# Predicted Answer: 1948 сылтан баран 28-күүстэрэ, уонна 25-үрдүүттэн нэһигэр 27 кириэ�
# --------------------------------------------------------------------------------
# Question: Палеоклиматологтар ханнык күн-дьыл уратытын туһунан информацияны баҕаралларый?
# True Answer: климат
# Predicted Answer: Тураныһыыныһа, уонооҕа санаабыт киһини уонна билиһитэ ССРС-НДР уонна Россия ССР
# --------------------------------------------------------------------------------
# Question: Цианобактериялар клеткаҕа төһө өр киирбиттэрий?
# True Answer: миллиард сыл анараа өттүгэр
# Predicted Answer: Элбэстэктэрэ туруута ылбыттарын, барын да үлэтин элбэстэктэрэ, хана өлб�
# --------------------------------------------------------------------------------
# Question: Кэнники кэм аата ким диэний?
# True Answer: Голоцен
# Predicted Answer: Арытык ким дьоно?
# --------------------------------------------------------------------------------
# Question: Ньюкасл куорат киининэн ханнык тоннеллар тутуллалларый?
# True Answer: дириҥ таһымнаах
# Predicted Answer: Куораты Тайн уонна Уэр үгүс өттүн хабар куорат таһынааҕы уонна сир аннынаа
# --------------------------------------------------------------------------------
# Question: Аарон Спеллинг ханнык драмата 80-с сылларга ABC ханаалга тахсыбытай?
# True Answer: Династия
# Predicted Answer: "Happy Days" диэн билигин "Фортуннан куруо" диэн түспитэ, Үрдүлдүгҥа, мохтооччуурда
# --------------------------------------------------------------------------------
# Question: ABC түөрт ноталаах ырыата ханна билигин да туттулларый?
# True Answer: ABC по запросу
# Predicted Answer: Олохтоохторун бэйэлэрэ ылыммына, АНТВ-ты уонна ABC түөрт ноталаах ырыата ылыбыта
# --------------------------------------------------------------------------------
# Question: Манакинтаунҥа хас олохтоох киһи олохсуйбутай?
# True Answer: 390
# Predicted Answer: Да буолар!
# Аатыт: Булууба
# Маппын үтүөннэрэ: 1,000 км² (395 sq mi)
# Хэлэмэ
# --------------------------------------------------------------------------------
# Question: Икбал хас сыллаахха Лахорга төннүбүтэй?
# True Answer: 1908
# Predicted Answer: Дьоппуу кута, халаттар кыа, эппиэттигэр олохсуйан!
# --------------------------------------------------------------------------------
# Question: Сири эбэтэр баайы-дуолу хайдах туһаныахха сөбүн ким быһаарарый?
# True Answer: Шотландия бырабыыталыстыбата.
# Predicted Answer: Кэбиэһинэн сокуон барыннар киирбит кэминэ 2 олоҕурар сиринэ Сканза гэмниисигэр таһымна
# --------------------------------------------------------------------------------
# Question: Эйнштейн ханнык физика моделын оҥорботоҕой?
# True Answer: бэйэтэ сөп түбэһэр түмсүү
# Predicted Answer: В. П. Анофриев. Билигин электроннай күүстэригэр тус-туранньара ортохторго дьахталлар. / Б
# --------------------------------------------------------------------------------
# Question: Музыкальнай инструменнар галереяларын сабыыга эппиэттиир Ил Түмэн саайтыгар онлайн-петицияҕа төһө киһи илии баттаата?
# True Answer: 5100 тахса
# Predicted Answer: Сабыын иллии чотурттуогуллубут буоларын икки 1000 км²-ийэ тутулара суох буолбута, хааныга бэй
# --------------------------------------------------------------------------------
# Question: Коммерческай туһаныыга уустук кислород хаһан оҥоһуллубутай?
# True Answer: 1895
# Predicted Answer: Газдыҥ көмө сэрии барынан үчүгэйтэ суохтар!
# Ойдуоноона билигин үеде тупсаллара
# --------------------------------------------------------------------------------
# Question: Полония дьиэтэ ханна баарый?
# True Answer: Конвикторскай уул.
# Predicted Answer: Яэндэллэр, Польшалааҕа саналан да ылбыта?
# --------------------------------------------------------------------------------
# Question: Маккинзи уонна хампаанньаны ким тэрийбитэй?
# True Answer: Джеймс О. Маккинзи
# Predicted Answer: Премьер-министрҕэ олохтон ааттаахтыллар?
# Иргэниэнэр: Тэһийэ буолбута.
# Мунна сэрбиэтит
# --------------------------------------------------------------------------------
# Question: Сайыҥҥы тыйаатыр ханна баара буолла?
# True Answer: Саксонскай саад
# Predicted Answer: Бу тыйаатыр диэн сайдыытааннарын мөччөлээхтэрэ, өйдьөх чылар үрд�
# --------------------------------------------------------------------------------
# Question: Амазонка ойууругар аан дойду углерода төһө кээмэйэ мунньулларый?
# True Answer: 10%
# Predicted Answer: Углерод бассейнэ ирдэлээһинэ эрэ буолан үчүгэйэ 7,2 ± 3,9 %; Амазонка ойу
# --------------------------------------------------------------------------------
# Question: 1935 сыл кэнниттэн ким Рейнландка киирэрин бобуохтарай?
# True Answer: Германия аармыйата
# Predicted Answer: 1942 сыл кэнниттэн Рейнланд ойдухоотугу өҥүөрүттэн нэрдэрэ, онтон киирэрбит
# --------------------------------------------------------------------------------
# Question: Ханнык биллэр ааптар суруйуутугар Перси Шелли майгыннаһыытын уонна майгыннаһыытын туһаммытай?
# True Answer: Генри Дэвид Торо
# Predicted Answer: Эппиэт тартан уһун кэннеҕэ АНТ-тиирдигэр уонна Ганди олус таһымнарааһыннын б
# --------------------------------------------------------------------------------
# Question: Брукхейвен ханнык сирэ билигин даҕаны буруйу оҥоруу үрдүк таһымынан биллэрий?
# True Answer: Изолированнай подразделение
# Predicted Answer: Күүстэммит олоҕо ньуутун дьиэтиигэ, дьааһааҕыйннур түөһөн
# --------------------------------------------------------------------------------
# Question: Тесла хас сыллаахха өлбүтэй?
# True Answer: 1943
# Predicted Answer: Билларга Тесла диэн эмиэ кинниһитэ айымньыларын дьайыыһаҕа олун баар. Кини 1958
# --------------------------------------------------------------------------------
# Question: Иммунодефицит тугу үөскэтэрий?
# True Answer: хатыланар уонна олоххо кутталлаах инфекциялар
# Predicted Answer: Аутоиммуннай систиэмэ тугу биллиитин сыыҥһаҕа үөскэтэр.
# Билиэктэр: Кэлин
# --------------------------------------------------------------------------------
# Question: Амазонка ойуура диэн ханнык ойууруй?
# True Answer: сииктээх киэҥ сэбирдэхтээх ойуур
# Predicted Answer: Амазонка ойуур – бу уонна өттө кыылан саһыыларга тардылларыгар өрүспийдьэй
# --------------------------------------------------------------------------------
# Question: Франция өрөспүүбүлүкэлэрэ Франция империятын тутууну хаһан өйөөбүттэрий?
# True Answer: Германия бэйэтин колониальнай империятын тутар буолбутугар
# Predicted Answer: Нарын биир эрэр эмиэ үрдэлээҕэ тустубатынан ордук элбэтиир. Уопсан кэлэ: С
# --------------------------------------------------------------------------------
# Question: 1955 сыллаахха тахсыбыт ырытыыга олоҕуран, баайдар мунньуллубут харчылара тугу саптарар дии саныыллара буолла?
# True Answer: атыылаһааччы ирдэбилэ кыччаабыт
# Predicted Answer: Эппиэт - буоланнаах сыыппалахтыыга, дьайыытын саналаһын икки эссэргэ, атыттар эрэ
# --------------------------------------------------------------------------------
# Question: Бурджесс сланецыгар булуллубут окаменелостарга туох тиийбэт этэй?
# True Answer: щупальцалар
# Predicted Answer: Элбеттэринэн тэҥ эдэнииттэн бэлэнииттэн, өҥҥэ балаҕанар диэн арыыллыбыт
# --------------------------------------------------------------------------------
# Question: Ханнык оонньооччу 2-тэн мээчиги киллэрбитий?
# True Answer: Андерсон
# Predicted Answer: Сирэһииттэн сүүрүктэҕэ хостообурдуохтуу!
# Ойубат: Олоо ыстатыйа, эппи
# --------------------------------------------------------------------------------
# Question: Суперкубокка оонньообут саамай кырдьаҕас квартербек рекордун ким тутан олорбутай?
# True Answer: Джон Элвей
# Predicted Answer: Кад тэҥ кинигэр киириитэ сылыта атыырын туруохтар, тостой элбэтиир этэ үксэр үйэл
# --------------------------------------------------------------------------------
# Question: 1999 сыллаахха тахсыбыт ыстатыйа информациятын ханнык реконструкциялар өйөөтүлэр?
# True Answer: Джонс уонна атыттар 1998, Поллак, Хуанг уонна Шен 1998, Кроули уонна Лоуэри 2000 уонна Бриффа 2000
# Predicted Answer: Улахан сайдааҕылаах ыстатыйа туһалаах элбэки инфраструктураҕа олорооччулар уонна орто үй
# --------------------------------------------------------------------------------
# Question: Тэмүджин хаһан монголлар хааннарынан талыллыбытай?
# True Answer: 1186
# Predicted Answer: Уһуулаах кыттыһынан кыраах!
# Яг: Соруйаан да эмиэ тэмүджин кыраны, яган! Ылы б
# --------------------------------------------------------------------------------
# Question: Ктенофордар күҥҥэ төһөнү сииллэрий?
# True Answer: бэйэлэрин ыйааһыннарыттан уон төгүл элбэх
# Predicted Answer: Оҕолору күүһүнээх диэһэ иитинэн билиитэ.
# Кеҥҥэ сытыаллара (филумын)
# --------------------------------------------------------------------------------
# Question: Паар турбинатын турбинаҕа киирэр температурата төһө буоларый, кыраадыһынан?
# True Answer: 565 °C
# Predicted Answer: Энергия үлэни икки кэриҥэ электроэнергияга ойуттан киирэр.
# Топпалары:
# Преимущества
# Б
# --------------------------------------------------------------------------------
# Question: Бастакы интернет2 ситимэ ким диэн ааттаах этэй
# True Answer: Абилин
# Predicted Answer: Интернет2 ситимэ ким диэн ааттаах этэй
# Интернээтиэн туллубута: Сотыйаан: ХХХI куруук – XXI-кылым
# --------------------------------------------------------------------------------
# Question: Илиҥҥи Европа ханнык улахан куораттара монголлар саба түспүттэрэй?
# True Answer: Новгород уонна Псков
# Predicted Answer: Эппиэт - Илиҥҥи Европа улахан куораттара Монголдар саба түспүттэрэй. Сургуруохтуок
# --------------------------------------------------------------------------------
# Question: Тоҕус уонна Онус быраастар иккис табаарыстара кимнээх этилэр?
# True Answer: Микки Смит (Ноэль Кларк) уонна Джек Харкнесс (Джон Барроуман)
# Predicted Answer: Чичуу, чугас тирбийнэн эбит!
# «Героей» да диэн тахса кырыттан туспаттарга, сүүһү�
# --------------------------------------------------------------------------------
# Question: Аюрбарвада уола ким этэй?
# True Answer: Гэгээн Хаан
# Predicted Answer: Анаммыт саҕалы үйэлэргэ аҕалар
# Айаҕа аҕалар:
# Бэлиитикэ Саҕалар:
# Хому
# --------------------------------------------------------------------------------
# Question: АХШ-ка оскуолалары ханнык суут дьыалата араарбытай?
# True Answer: Браун утары Топика үөрэҕириитин сэбиэтин
# Predicted Answer: Сэбиэттиэхпитэ - АХШ үгүстэрэ
# АХШ-ка оскуолаларын ардыахтар уонна ордук араарар
# --------------------------------------------------------------------------------
# Question: Ханнык биллэр индеец дьайыылара гражданскай истибэтэх буолуунан ааҕыллыбыттарай?
# True Answer: Ганди
# Predicted Answer: Ааҕалар олохтоохтору тэһиитэ. Ити уонна куруук эбиттеэр дьайыыларын өрөб�
# --------------------------------------------------------------------------------
# Question: Дюкен Сен-Пьеры босхолуурга төһө киһини ыыппытай?
# True Answer: 40
# Predicted Answer: Айа хайа бигэлээх суох дьааскатын үрдүк сирдээхтэрэ көһөн.
# Дюкен С
# --------------------------------------------------------------------------------
# Question: Джон Шипшенкс музейга улахан наследствотын сыала-соруга туох этэй?
# True Answer: 'Британскай искусство национальнай галереятын' тэрийии
# Predicted Answer: Мускулатыйа таһымын ахсаана эрээри, Британия дойду суруйаллара.
# --------------------------------------------------------------------------------
# Question: Уһун дистанцияҕа сүүрүү эйгэтигэр ким баһыйарый?
# True Answer: Кения спортсменнара (ордук Календжин)
# Predicted Answer: Да үксээн дьоҕурттан?
# --------------------------------------------------------------------------------
# Question: Sky Movies уонна Sky Box office эмиэ ханнык эбии саундтректары киллэрэллэрий?
# True Answer: Dolby Digital
# Predicted Answer: Айыыллаах буолар?
# --------------------------------------------------------------------------------
# Question: SR 99 судаарыстыбалар икки ардыларынааҕы стандартарга сөп түбэһиннэрэн тупсарыы баҕатыгар туох биричиинэлэр дьайалларый?
# True Answer: SR 99 устун куораттарга нэһилиэнньэ ахсаана уонна тырааныспар түргэнник элбиирэ, ону тэҥэ федеральнай үбүлээһин баҕалаах буолуута
# Predicted Answer: "Айыын" киин сиргэ киирэр хайдах көстүүн көтөрүүгэр таһааралл
# --------------------------------------------------------------------------------
# Question: Ханнык кэм-кэм суола космоска токур линия быһыытынан көрүллэрий?
# True Answer: баллистическай траектория
# Predicted Answer: Эптээмиэгэ эрэ үчүгэй күүс талаҕана. Талалыырынан норуоттарын буолуон са
# --------------------------------------------------------------------------------
# Question: Ыйааһыннар уонна кээмэйдэр генеральнай конференциялара 1960 сыллаахха Тесла аатынан туох диэн ааттаммытай?
# True Answer: Магнитнай поток тыыһыынчатын SI биригээдэтэ
# Predicted Answer: Система атын эртээх ситимэнэ ордук, ол дойду үгүс атын эртээх ситимэнэҕа а
# --------------------------------------------------------------------------------
# Question: V&A ханнык аан дойду быыстапкатыттан төрүттэммитэй?
# True Answer: 1851 сыллааҕы Улахан быыстапка
# Predicted Answer: Айаҕа үлэнииммааҕа бэйээтэр.
# --------------------------------------------------------------------------------
# Question: DECnet бастаан тугу оҥорбутай
# True Answer: икки PDP-11 мини-компьютеры холбоо
# Predicted Answer: Unix, BSD, Solaris
# Тунус:
# Уопсалар:
# Носок: Общественный стандарт — Open Systems Interconnection (OSI) модели.
# Датамадьынын уонна мэл
# --------------------------------------------------------------------------------
# Question: НАСА ханнык сирэ LOR идеятыгар бүтэһигин кэлбитэй?
# True Answer: Маршалл космическай көтөр киинэ
# Predicted Answer: Кини ылыллыбыта NASA киирэн олус куоракка мөлүөхтээх ырыа көмүлбэлэрит
# --------------------------------------------------------------------------------
# Question: Судаарыстыбаннай оскуолалары кытта, Соҕуруу Африка оскуолаларын туһунан сокуонунан ханнык оскуола билиниллибитэй?
# True Answer: тутулуга суох
# Predicted Answer: Туһаарыллыбыт олоҕурун иһин тэриллибит соҕуруу Африка оскуолаларын тутууһунан били
# --------------------------------------------------------------------------------
# Question: Америкаҕа үһүс баай киһи кимий?
# True Answer: Ларри Эллисон
# Predicted Answer: Төрүттээччитэ билэҕэ!
# --------------------------------------------------------------------------------
# Question: WG I Summary for Policymakers отчуотугар киһи дьайыыта парниковай гаастарга туох дьайыылаах диэн этиллэрий?
# True Answer: атмосфера мунньуллуутун биллэ үрдэтии
# Predicted Answer: Эппиеттэрэ аан дойду уонна сулууспатын үйэҕэ, ааҕар, ол ортон сэргинэ иһитт
# --------------------------------------------------------------------------------
# Question: Ким 1915 сыллаахха атыыласпытай?
# True Answer: Эдисон
# Predicted Answer: Газеттерингэр 1922-2011 чөөн ылбыт.
# Версия: Угартар хооронунда.
# --------------------------------------------------------------------------------
# Question: Ханнык спутник Sky Digital саҥа цифровой сервиһи таһаарарга көмөлөспүтэй?
# True Answer: Eutelsat's Eurobird 1
# Predicted Answer: Эпитектен олорооччул, чугай Үрдүүртүнэнэр үйэһиттэн билиэхэ диэн ааттан
# --------------------------------------------------------------------------------
# Question: Кузнецовскай кривая этэринэн, экэниэмикэ сайдыытын кытта, тэҥэ суох буолуу туох кэнниттэн аҕыйыаҕай?
# True Answer: бастакы улаатар
# Predicted Answer: Аны олохтооччу СМИ-ныһа хамсара, баттама санааларыгар Кузнецовскай кривой гипотезаны үөрэ
# --------------------------------------------------------------------------------
# Question: Виктория парламена ханнык докумуонтан тэриллибитэй?
# True Answer: Виктория Конституциятын сокуона 1855
# Predicted Answer: Виктория парламена ханнык документуон тахсыбытай, ол ааттаах хампаҥ ахсааныга эйгэ ылыммыта, ол эб
# --------------------------------------------------------------------------------
# Question: Тесла олоҕун үгүс өттүгэр ханна олорбутай?
# True Answer: Нью-Йорк гостиницалара
# Predicted Answer: TESLA - Elon Musk
# Elon Reeve Musk is an American entrepreneur and investor who has been called the most influential person in history. He co-founded PayPal with Peter Thiel as well as SpaceX, Tesla Motors, The Boring Company,
# --------------------------------------------------------------------------------
# Question: Y бастакы вариана хайдах уонна хаһан тахсыбыта. pestis Европа5а киирэр да?
# True Answer: Марсель пордунан 1347 сыллаахха ахсынньы эргин
# Predicted Answer: I. Кейбэтэ баран билиитин биэр уонна билиитин биэр үүнэ. Олунньуттан 1946 сылҕаа�
# --------------------------------------------------------------------------------
# Question: Никсон кинини хаһан талбытай?
# True Answer: 1973
# Predicted Answer: Көскөө, кинини бэйэтин билээр!
# Никсон мандата айталаммыт.
# CIA - "The CIA has been involved in a massive cover-up of
# --------------------------------------------------------------------------------
# Question: Джон Элуэй Суперкубок XXXIII оонньууругар хас саастаах этэй?
# True Answer: 38
# Predicted Answer: Айымаха тэриллибэттэх, Суперкубок үрээх кииспэкэ суох диэн эппиттэрэ.
# Атынан
# --------------------------------------------------------------------------------
# Question: Кытай националистара инники күөҥҥэ сылдьар Кытай хомуньуус күүстэриттэн мавзолейы ханна көһөрбүттэрий?
# True Answer: Синин аттыгар баар Кумбум манастыыра эбэтэр Таэр Ши
# Predicted Answer: Ухар чулуу үөрүүүтүнэ буолбуттара?
# Илэлэ: Биринчилээх кэспитинэ?
# М
# --------------------------------------------------------------------------------
# Question: Эдиакарнай эоандромеда тугу көрдөрөрүнэн ааҕыллыан сөбүй?
# True Answer: тараах желе.
# Predicted Answer: Эдиакар Эоандромеда көрдөрүөн тохсунньу 2004 сыллаахха бэйэлэрэ суох 5 кү
# --------------------------------------------------------------------------------
# Question: Ганди үлэтэ туох диэн ааттаах этэй?
# True Answer: Сатьяграха
# Predicted Answer: Араббааҕын туску саҥа дьаардыытын хаһайан буолуохтаах!
# Соруйаан: Уһунньуга
# --------------------------------------------------------------------------------
# Question: Пейтон Мэннинг Суперкубок 50 оонньуутугар хас саастаах этэй?
# True Answer: 39
# Predicted Answer: Олунньу 21-да, 1993 сыллахха таллыбаабытта эмиэ Токио хотугайдарына түспиттеэһигэр Д
# --------------------------------------------------------------------------------
# Question: ТУМАС президена кимий?
# True Answer: Преподобнай Пол Т. Столсуорт
# Predicted Answer: Секс-библиятын нууччута баҕаарыыларын талҕантан
# Холбоһуктаах Методистскай Церковь ы
# --------------------------------------------------------------------------------
# Question: Дойду гимнын ким ыллаабытай?
# True Answer: Леди Гага
# Predicted Answer: Ву дьэ айымньытыгар норуот буолбуттара!
# Муссигалар: Сэйлер Кенни гэһэн дойдутугар бииргэ аат
# --------------------------------------------------------------------------------
# Question: BSkyB стандартнай быһаарыылаах биэриилэрэ туохха сөп түбэһэллэрий?
# True Answer: DVB-га сөп түбэһэр MPEG-2
# Predicted Answer: Кинотеатраллаах буолан ДВБ-системалаах телевизиялыырыгар тылҕараан сөп!
# KODAK DCR-MX9000 Camera Review
# The Kod
# --------------------------------------------------------------------------------
# Question: Бу кылгас болдьохтоох тэрилтэ тоҕо тэриллибитэй?
# True Answer: эмбаргоҕа эппиэти сөп түбэһиннэрэргэ
# Predicted Answer: Деҥэ буолуон сөптуохтун тулкулларын тахсыбыттар?
# Даандааҕа суохтун тулкулларын
# --------------------------------------------------------------------------------
# Question: Бастакы методистскай духовенствоны ким анаабытай?
# True Answer: Джон Уэсли
# Predicted Answer: Электроннай библиотека
# Оккультный сайт для изучения английского языка (неформат) / Издательство «Богемия» / 1997 год
# Воспри
# --------------------------------------------------------------------------------
# Question: Виктория арҕаа өттүгэр сорох линиялар төһө кээмэйгэ уларыйбыттарай?
# True Answer: 1,435 мм (4 фут 8 1⁄2 дюйм) стандартнай калибр
# Predicted Answer: Кыаһаҕастааҕа 60 км (37 миль) биирдийин кулуусунан холбууранан 7-10 саамай километрийга
# --------------------------------------------------------------------------------
# Question: Илиҥҥи Германия бүтэһик премьер-миниистирэ ким этэй?
# True Answer: Лотар де Мезьер
# Predicted Answer: Кэмнэтигэр уоллар билигэр ньигэр чуорааттан көрдүүттэр, уоллар чуораат
# --------------------------------------------------------------------------------
# Question: Фаунальнай сукцессия принцибэ ким эволюциятын теориятыттан 100 сыл иннинэ оҥоһуллубутай?
# True Answer: Чарльз Дарвин
# Predicted Answer: Ол урукка тупутунан, Смиттэринэн уонна Darwin-динэрэ уурайааччын быһыытынан үөскээбит
# --------------------------------------------------------------------------------
# Question: 2015 сыллаахха Пантердар көмүскэллэрэ төһө перехваттары оҥорбуттарай?
# True Answer: 24
# Predicted Answer: Говард Моос да айарыта, НФЛ 16 эрэ 12 сактарына күһэллибит төрүттэрэ.
# Ре
# --------------------------------------------------------------------------------
# Question: Паар массыынатын үлэтин бэрэбиэркэлииргэ ханнык тэрил туттулларый?
# True Answer: паровой двигатель индикатора
# Predicted Answer: Сабыттааһын сабатыгар хаһаайыстыба эбэтэр индикатор тургустубуттар?
# --------------------------------------------------------------------------------
# Question: Чингисхан удьуордарыттан ким мамлюктары Палестинаттан үүрэн таһаарбытай?
# True Answer: Газан Хан
# Predicted Answer: Балагааһа элбэк буолан баҕаһынын туһунан үрэйбитэ. 1388 сыллаахха Чингисхан
# --------------------------------------------------------------------------------
# Question: Билиҥҥи ктенфора суох ктенфораларын көрдөрөр туох окаменелостары булбуттарай?
# True Answer: щупальцалар
# Predicted Answer: Харамайдар ктенофордарын өлөрүнэ сокунааҕа анаан кыттыбыта?
# Монография "Евроценский вопрос и
# --------------------------------------------------------------------------------
# Question: 2000 сыллаахха Амазонка ойуурун хас квадратнай килэмиэтирэ сүппүтэ буолла?
# True Answer: 587,000
# Predicted Answer: 2,7 млн км²
# Ошунньу 22.01.2019
# Амазонка ойуур — 2,7 миллиард километр²
# Амазонка уруо о
# --------------------------------------------------------------------------------
# Question: Төрөппүт уоппускатын директивата хаһан оҥоһуллубутай?
# True Answer: 1996
# Predicted Answer: Төрөппүт уоппускатын директива ылыммыта ол сүбэлэрин, уйдьана сүрүн эмиэ
# --------------------------------------------------------------------------------
# Question: Проблемнай экземпляр строкатын атын термина тугуй?
# True Answer: битстрокалар
# Predicted Answer: Уччаны мунньухтара хоҕулуктаах иһигэр, ылынытара ыһыллыбыт итилээх матрица буол
# --------------------------------------------------------------------------------
# Question: Европа Сэбиэтэ хаһан биир тэрилтэҕэ Киһи быраабыгар Европа хартыынатын оҥорорго сорудахтаабытай?
# True Answer: 1999
# Predicted Answer: Европейский договор 1948 г.
# Ордук: 28-га айымньыныһа, Кейэҕэй сиргэ Урускалыыр Кейэҕэй сирг
# --------------------------------------------------------------------------------
# Question: Виктория конституциятыгар ханнык бөлөх уларытыан сөбүй?
# True Answer: Виктория парламена
# Predicted Answer: Ишэхэ Виктория конституацияттан 10% тэһимини сэбиэт буолуута.
# Олохтонуонньуга: Виктория конституацияты
# --------------------------------------------------------------------------------
# Question: Кирни бульвара ким аатынан ааттаммытай?
# True Answer: М. Тео Кирни
# Predicted Answer: Бу төпүттэн 50 км тиийэлэр, барынан 15 км өссө ордук.
# Киһиттэрэ Кир
# --------------------------------------------------------------------------------
# Question: Муора уутуттан иһэр ууну перегонкалыыр туһунан ким суруйбутай?
# True Answer: Аль-Муваффак
# Predicted Answer: Ваалларын ыккарсыыта, төгүллээбит эрэ ураннайырын олохтоммуттара.
# Латина диэпти
# --------------------------------------------------------------------------------
# Question: Норманнар Анатолияҕа кимниин холбоспуттарай?
# True Answer: Турция күүстэрэ
# Predicted Answer: Кыраанньарын суох эйэ кытыллаахтарыттан (Армениан) орто диэки нуур-оҥуопсан хаҕарал
# --------------------------------------------------------------------------------
# Question: Элвей 38 сааһыгар ханнык Супербоулга кыайбытай?
# True Answer: Супербоул XXXIII
# Predicted Answer: Ресми риксибиин Супербуула таптыахта, эппиэттиир.
# Soccer fans have been hoping that the game would be played by a club from the U.S. for some time
# --------------------------------------------------------------------------------
# Question: Амазонка ойуурдара Сир ойуурдарын төһө ахсаанын ылалларый?
# True Answer: аҥарыттан тахса
# Predicted Answer: Амазонка ойуурдарын эппиэттэргэ 18%-тан аҕыйахтар, 12%-тан суохтар. Сырыылаахтар 70
# --------------------------------------------------------------------------------
# Question: Мартин Лютер саҕана туох ирдэнэр этэй?
# True Answer: Немец тыллаах таһаарыылар
# Predicted Answer: Владимир Ильич Ленин – советский революционер и партизан, учёный, драматург, публицист, писатель.
# Теологийнай албан туттарар э
# --------------------------------------------------------------------------------
# Question: Исламскай судаарыстыба 2014 сыллаахха бэйэтин туох диэн биллэрбитэй?
# True Answer: халифат
# Predicted Answer: Аныгы кытта тыммыытан арыллар көмүк санаалара Саҥардыыр 2000-с сылларга таһаарбыта
# --------------------------------------------------------------------------------
# Question: Мельбурн рабочай кылаастаах куорат таһынааҕы бөһүөлэктэригэр ханнык политическай баартыйа саамай күүстээх буолуой?
# True Answer: Австралия лейбористскай партията
# Predicted Answer: Кини эмиэ чугас уонна биир олохтоохторун туһунан уонна төрдөгүннэрэ уонна сынньор
# --------------------------------------------------------------------------------
# Question: Ханнык хампаанньаҕа оригинальнай ленталары төннөрө сатыыр сорудах бэриллибитэй?
# True Answer: Лоури Диджитал
# Predicted Answer: Саҥардыллыбыт видеотураллаах суох эркиллэр буолар.
# Испеттэр: Кини 30-с тунуску дьиҥҥ
# --------------------------------------------------------------------------------
# Question: Аан дойдуга бары ископаемайдар биир кэмҥэ булуллубаттара бу принцип туох буоларыгар тириэрдэр?
# True Answer: комплекс
# Predicted Answer: Кэһэһэгэ тус-туспа, аан дойду куоракка 30 милин үөскээп чураабатаҕа буолбуттар
# --------------------------------------------------------------------------------
# Question: ЮАР хамсааһыныттан тэйии хаһан буолбутай?
# True Answer: 1980-с сыллар бүтүүлэригэр
# Predicted Answer: Арын таҥылаахтар уонна суруйааннар үтүүттэн босуптуп, САФ 1979 сыл күнүг
# --------------------------------------------------------------------------------
# Question: Тесла электрическэй ыытааччы патенын хаһан ылбытай?
# True Answer: 1900
# Predicted Answer: Кэмиэхтэ санара Москообурда Д.Тесла саһаҕа сынньаммыт үс бириэнинэ.
# Биэрэлл
# --------------------------------------------------------------------------------
# Question: Ханнык биллэр индеец гражданскай непокорность оҥорбутай?
# True Answer: Ганди
# Predicted Answer: Эппиэттигэр 1880 сылтан эбэтэр 1890 сылларыгар баран олорбут Сатяграха олоҕун атынга тус-
# --------------------------------------------------------------------------------
# Question: Бу бырачыастартан үгүстэрэ туох сыаллаахтарый?
# True Answer: боппуруостарын остуолга таһаар
# Predicted Answer: "Догондооҕа, суох буолуу бэйэтэ чөҕө өтө маннык көһүүлээһ
# --------------------------------------------------------------------------------
# Question: Массыыналары туһаныытын таһынан, соҕуруу Калифорния өссө тугу туһаныытынан биллэрий?
# True Answer: улахан суоллар
# Predicted Answer: Аан дойду Союза ССРА бэйэлэриниирин суруйуур, тугу тылын уонна олохтооҕо 1000 миллиард долл
# --------------------------------------------------------------------------------
# Question: Биирдиилээн гражданскай истибэт буолуу сыала-соруга тугуй?
# True Answer: сорох сокуоннары дьайыыта суох оҥорор
# Predicted Answer: Мыльбалдынан соҕонон эргэ сокуоннарын өйүнэн-санаатынан биирдиилээн гражданиыны ордук
# --------------------------------------------------------------------------------
# Question: Ресницалар туохха туттулларый?
# True Answer: хамсаныы ньымата
# Predicted Answer: Эпикритион - оруоҕуна үйэлээхтэрэ «Түү» диэбэҕитэ, онтон эппиэтэ,
# --------------------------------------------------------------------------------
# Question: Джеральд Ратнер атлетика киинэ хаһан тутуллубутай?
# True Answer: 2003
# Predicted Answer: Туһаныылара
# Иттэхтэрэ, эппиэт туппуттан туһунан Стивен Бейли, Филиппиналарыгар эпп
# --------------------------------------------------------------------------------
# Question: Людвиг Мис ван дер Роэ ханнык дьаһалтаны тутарга анаабытай?
# True Answer: Социальнай сулууспа салалтатын оскуолата
# Predicted Answer: Филипп Кейтлин О'Грей (Филли) - тупсаан өлөҕө 1972 сыллаахха тураҕанньыыга эл
# --------------------------------------------------------------------------------
# Question: Бразилия аан дойдуга соя оҥоһуутугар ханна турарый?
# True Answer: аан дойдуга иккис улахан оҥорон таһаарааччы
# Predicted Answer: Кэлин олоҕор Ханнык көмүк буолар.
# Алым, өссө сүрүүрүктэрэ тост
# --------------------------------------------------------------------------------
# Question: Анархистар туох биричиинэнэн накаастабылы ылыныахтарын баҕарбаттарый?
# True Answer: атын дьон быраабын кэспэт
# Predicted Answer: Накаастабылы ылыныахтарын суохтара сылдьар улахан дьон үрдүк сирэ аһытынан ылыныах
# --------------------------------------------------------------------------------
# Question: Ханнык Пантерс оонньооччута пенальтины ылбытай, ол Бронкостарга саҥа түһүүлэри биэрбитэ?
# True Answer: Джош Норман
# Predicted Answer: Быстыын туппута!
# <p><a href="http://www.mlb.com/nfl/teams/pittsburgh-panthers">Pittsburgh Steelers</a>, <a href="http://www.mlb.com
# --------------------------------------------------------------------------------
# Question: Стратиграфтар ханнык көрүҥнээх хостооһун сирдэрин була сатыылларый?
# True Answer: углеводород
# Predicted Answer: Stratigraphy – “стратография” диэн ойохтор. Синий норуотун тарҕата. Туллубут буларын суол, бүтүннэ
# --------------------------------------------------------------------------------
# Question: Джексонвилл ханнык историческай киһи аатынан ааттаммытай?
# True Answer: Эндрю Джексон
# Predicted Answer: Гербуур Хостер, Джексонвилл хайыһа, бэйэ ийи сиргэ ботторуттар Ирландияга баар. Уонна 1819 сы
# --------------------------------------------------------------------------------
# Question: Хлоропласт ДНК-тын синонима диэн тугуй?
# True Answer: пластома
# Predicted Answer: Сыыһаны кылгата, мөччи сөбүт
# Ойдуот: Эбит тэҥэ сокуон
# Поздравляеһин: О
# --------------------------------------------------------------------------------
# Question: Соҕурууҥҥу Калифорния нэһилиэнньэлээх пууннара улахан, тарҕаммыт буолаллара биллэр, уонна өссө туох майгылаахтарый?
# True Answer: куорат таһынааҕы
# Predicted Answer: Бо бастакы олохтоохторо буоларга, урукку олохтоохторо быыһатыгар аҕайдаабыттар, уонна барыыны
# --------------------------------------------------------------------------------
# Question: Ураган күүстэрин кээмэйдиир шкаланы туох диэн ааттыылларый?
# True Answer: Саффир-Симпсон шкалата
# Predicted Answer: Дьайыын кэмҥэ саамай ныманынан билиитигэр, онтон дьиһэ киһиһин иһигэр буору
# --------------------------------------------------------------------------------
# Question: Энергипроект АБ мотуора үрдүк баттааһыннаах мотуор эффективноһын хас бырыһыанын ситиспитий?
# True Answer: 27-30%
# Predicted Answer: Сайт хоһооннук таһымнаахтара 2006 сыллаахха айылҕатынан барбыттар.
# Вопрос: Истиль диэри дь
# --------------------------------------------------------------------------------
# Question: Перотти 1996 сыллаахха оҥорбут чинчийиитэ тугу чинчийбитэй?
# True Answer: тэҥэ суох буолуу экономическай үүнүүгэ дьайыан сөптөөх ханааллар
# Predicted Answer: Сомбу уонна кийэрэ тугу чинчийбитэ.
# Олоҕур, тэҥэ суох буолуутун хомуйалааҕа тугу чинчий
# --------------------------------------------------------------------------------
# Question: Гражданскай истибэтэхтэргэ сороҕор туох накаастабыл оҥоһулларый?
# True Answer: сөбүлэһии
# Predicted Answer: Суруктаах сываҕа чуол киһи аныктамааттар.
# Аҕаҕа үрдүк үөрэтииллэр: Н
# --------------------------------------------------------------------------------
# Question: Монголлар хаьан Траннарга хотторбуттарай?
# True Answer: 1288
# Predicted Answer: Уччарын ньымнар, яэрэһийэ - Хубилай, бастаанан Даян Улуу олорбута, үрүсү�
# --------------------------------------------------------------------------------
# Question: Соҕуруу Африка оскуолаларын туһунан сокуон хас сыллаахха ылыллыбытай?
# True Answer: 1996
# Predicted Answer: Саха дойдуларыгар суох буолбут үчүгэй чоҕотугар атын ордук аналарыныҥ иллии сылга
# --------------------------------------------------------------------------------
# Question: 1700-с сылларга Францияттан хас гугенот куоппутай?
# True Answer: 500,000
# Predicted Answer: Гугеноты ССРС-га саҥарыгар төрдөгү көмө ааттарынан кыттыһаммыт.
# Бу аат
# --------------------------------------------------------------------------------
# Question: Кипиддидтар диэн туох буолбатахтарый?
# True Answer: монофилетическай
# Predicted Answer: Кипиддидтар буолбатахтарый?
# Билигин: Кипиддидтар диэн туох буолбатахтарый?
# --------------------------------------------------------------------------------
# Question: Лютер бүтэһик этиитин ханнык чааһа немецтии этэй?
# True Answer: "Биһиги умнаһыттарбыт,"
# Predicted Answer: Да. Хайда өйөд эрэ, дьэлиини сытыс саһынан уоллах тээрэһиннэ.
# Soruyan
# --------------------------------------------------------------------------------
# Question: Sentanta Sports ханнык платформаҕа тахсар былааннаах этэй?
# True Answer: цифровой сирдээҕи
# Predicted Answer: Көстөрүүллэр, айар иһигэр олорбута эмиэ бу даҥа баар.
# Дьоруоҕу: Да хо
# --------------------------------------------------------------------------------
# Question: Диатомнар ханнык хлоропластардаахтарый?
# True Answer: кыһыл уу үүнээйитин хлоропласта
# Predicted Answer: Соруйаан. Дьиһэ аныгы диатомалар өбүгэлэрин кэннииттэн диатомаларга хомойбута диатаомал
# --------------------------------------------------------------------------------
# Question: Ханнык Ил Түмэн чилиэнэ музей коллекцияны хайдах харыстыаҕын уонна дьон-сэргэ көрөрүгэр таһаарыаҕын быһаарбытай?
# True Answer: Брайан Дэвис
# Predicted Answer: Музей дьоннуураларын кэминэн инициативалыы, онтон бэйэлээрэ бэлии аһарбытай эрэ, баар
# --------------------------------------------------------------------------------
# Question: Сайыҥҥы тыйаатыр төһө өр үлэлээтэ?
# True Answer: 1870 сылтан 1939 сылга диэри
# Predicted Answer: Туспата киирэйи, барын айымньыларын туспаан олорбутун маннык дьоҕурдууларын хомууктаах дь
# --------------------------------------------------------------------------------
# Question: Варшава бастакы биржата хаһан тэриллибитэй?
# True Answer: 1817
# Predicted Answer: Кини 2008 сылга 10 % аан дойдутааҕа 18 эркэтэ.
# Атын: Олоро Вячеслав Сергеевич Рудников - Варшав
# --------------------------------------------------------------------------------
# Question: Швейцария реформатын ханнык салайааччыта Лефевр үөрэнээччитэ этэй?
# True Answer: Уильям Фарель
# Predicted Answer: Швейцария реформатын салайааччыта Лефевр биле Реформация диэн буолбуттара.
# Рекорд: Кальвинизм таһаарыы
# --------------------------------------------------------------------------------
# Question: NTL өҥөлөрө туох диэн уларыйбыттарай?
# True Answer: Виргин Медиа
# Predicted Answer: Дьаһайарын тахса дьон Британияныга тэрийииллээхтэрин баҕас буолан баран Британия үлэҕэ
# --------------------------------------------------------------------------------
# Question: Сент-Джонс өрүһү 1562 сыллаахха ким хаартыскаҕа түһэрбитэй?
# True Answer: Жан Рибо
# Predicted Answer: Бу айымньыныһа үүдүүнүһүн сүрүннэрэ, 1979 сыллаахха 21
# --------------------------------------------------------------------------------
# Question: Күүс диэн өйдөбүл туох ыһыллыбат чааһа этэй?
# True Answer: Аристотель космологията
# Predicted Answer: Тыммына, хамааттан үрдүүрдэр, өйдөбүл сиргэ сахаларын хайдах үрдүү
# --------------------------------------------------------------------------------
# Question: ИПЦ шкалата тугу кээмэйдиирий?
# True Answer: судаарыстыбаннай секторга коррупция
# Predicted Answer: Коррупцияны байыарын икки үйэҕэ сабыыр!
# Эппиэт: Эпизод 1: Коррупцияны туруоруллуутун
# --------------------------------------------------------------------------------
# Question: 1915 сыллаахха бириэмийэҕэ хас кыттыгас туруорсуу баара буолуой?
# True Answer: 38
# Predicted Answer: Аныгы төрдүн саналлыбыта "Тесла" диэн аатын билэ.
# Бо дигиталай тытарыстыба олороҕор.
# --------------------------------------------------------------------------------
# Question: Амазонка регионуттан тахсыбыт айылҕа харыстабылын үлэһиттэрэ туохтан долгуйалларый?
# True Answer: үүнээйи иһигэр баар углерод
# Predicted Answer: Ээрэ тыммаһыттарын 2,4-3,7 тэҥэ ССРО диэри аһырынан улаханныык, эрдэтэ
# --------------------------------------------------------------------------------
# Question: Орто Дойду устун Хулагу Хаан тахсыытын ким тохтоппутай?
# True Answer: Египет мамлюктара
# Predicted Answer: Ол курда Арабыҥа хоһосуу эмиэ уруу кытта эрэ буруйдаабыттар көмүллүбүтт
# --------------------------------------------------------------------------------
# Question: Марли Матлин дойду ырыатын ханнык тылга тылбаастаабытай?
# True Answer: Америка жест тыла
# Predicted Answer: Соруйаан - Дьон иириттэн аныгы туран да үс биллэр. Эппиэттик эргийиэхтэринэн бу диэн аат
# --------------------------------------------------------------------------------
# Question: Оҕо үлэтин сорох биричиинэлэрэ туохтарый?
# True Answer: дьадаҥы буолуу, үөрэххэ тиийбэт буолуу уонна мөлтөх былаас тэрилтэлэрэ
# Predicted Answer: Соруйаан сэнигэс 1000 киһи дьиэтигэр араарыытын үөрэхтээх олохтоохторун
# --------------------------------------------------------------------------------
# Question: Ктенофордар диэн сабаҕаланар булуллубут окаменелосттар хас саастаахтарый?
# True Answer: 515 мөлүйүөн сыл
# Predicted Answer: Бу кэмигэр харыстыын эрэ кэмнэ тииттэн, саамай урато диэни кырдьаҕай сыл биир
# --------------------------------------------------------------------------------
# Question: Лос-Анджелес хас хамаандалаах этэй?
# True Answer: икки
# Predicted Answer: Агөөйэ эппиэт үлээх атыгар саамай уонна 20 сылы кыра таһаараан сатыаҕа, оло
# --------------------------------------------------------------------------------
# Question: Үксүгэр сөбүлэһии ылыы сыала-соруга тугуй?
# True Answer: хаайыы бириэмэтэ суох
# Predicted Answer: Сортобуттара уонна айылҕата, биле хамсарын аатта, сууруннар, кырааҕа айыыллаахтар, х
# --------------------------------------------------------------------------------
# Question: Бэдэрээтчиткэ толоруу ирдэбилэ бэриллибит буоллаҕына уонна бырайыагы бырайыактыыртан саҕалаан тутууга диэри ыытыахтаах буоллаҕына, толоруу ирдэбилин тутуһан туран, ханнык дуогабар бэриллэрий?
# True Answer: "бырайыактыыр тутуу" дуогабара
# Predicted Answer: Харамаҕа үс нээһийэ, кэтэриттериниэ, биир сүрэһигэр тутулларын, түм�
# --------------------------------------------------------------------------------
# Question: Хара өлүү аан бастаан туохха буруйдаммытай?
# True Answer: халлаан
# Predicted Answer: Тус да тосо!
# --------------------------------------------------------------------------------
# Question: Сорох гражданскай истибэтэх дьон тугу билиэхтэрин нааданый диэн саныылларый.
# True Answer: накаастабыл
# Predicted Answer: Эппиэттинэ сокуоннай уонна сокуоннай буоланнар тугу билиэхтэрин наадатын соруо.
# Накаччыта, сокуоннай
# --------------------------------------------------------------------------------
# Question: Гээген хаһан император этэй?
# True Answer: 1321 - 1323
# Predicted Answer: Оҕолоро тэрийэн таһаарар Үйэлэри арга-биллэр буолан, онтон, уолҕар иһигэр кии
# --------------------------------------------------------------------------------
# Question: Мельбурн ис регионнарыгар ханнык баартыйа салайарый?
# True Answer: Саһархайдар
# Predicted Answer: Лейбористарга эмиэ кэннэ Саһардарга салаахтан олохтооччуоҕа саһарар тииһэтиитэ.
# --------------------------------------------------------------------------------
# Question: Икбал кими кириитикэлиир этэй?
# True Answer: сүрүн Индия националист уонна светскай Индия Национальнай Конгреһа
# Predicted Answer: Чылык, культура, экономика, култууратын, урукку таһын эртэнньэ ыраата саҥара биирдэҕэ ин
# --------------------------------------------------------------------------------
# Question: Туох штаммнаах y. массовай могилаларга пестистар булуллубуттара дуо?
# True Answer: Ы. с. orientalis уонна Y. p. орто үйэлэр
# Predicted Answer: Олунньулугар 2013 сыллаахха атахтааҕа иран чума дьолуустарын эппиэттэрэ эрэ эмиэ к�
# --------------------------------------------------------------------------------
# Question: Бронкос кими кыайан АФК чөмпүйүөннэрэ буолбутай?
# True Answer: Саҥа Англия Патриоттара
# Predicted Answer: Патриоттар кими ахсааннаҕын күрээҕитэ үрдүнэн Нью-Энгланд олборсо көмү
# --------------------------------------------------------------------------------
# Question: Оскуола эндоуменын кээмэйэ төһө буоларый?
# True Answer: $37.6 млрд
# Predicted Answer: Саха тылааҕа билиитин таһааҕа суохтубут.
# Департаментта дьайым, Атын даха «Лас Вегас» м
# --------------------------------------------------------------------------------
# Question: Хас сыллаахха УМК чилиэнин былдьаары сорунуу буолбутай?
# True Answer: 2012
# Predicted Answer: Куоластааһын бэрэсидьиэниэхтэммитэ.
# Уруоҕа: Бу саҕаны санааллаҕа та�
# --------------------------------------------------------------------------------
# Question: Франция хаһан аан дойдутааҕы империятын чөлүгэр түһэрэргэ дьаныардаахтык саҕалаабытай?
# True Answer: кэнниттэн 1850
# Predicted Answer: Экономикалыыр, соһохторго санааллара сүрүннээн.
# --------------------------------------------------------------------------------
# Question: Чарльз өрүс кампуһун сорох чааһын холбуур муоста аата?
# True Answer: Джон У. Уикс Бридж
# Predicted Answer: Аһыттан Чарльз өрүс көмүкка барбыта?
# --------------------------------------------------------------------------------
# Question: Ктенофордар хас көрүҥнэрэ бигэргэммиттэрий?
# True Answer: 100–150
# Predicted Answer: Атын ктенофордарынын араас көрүҥнэр үөскэтэр кыаҕы биэрэллэр.
# Бил
# --------------------------------------------------------------------------------
# Question: Саҥа дойдуга гугеноттар итэҕэллэрин хайдах сайыннарбыттарай?
# True Answer: атын протестантскай конфессиялары кытта сибээстээх
# Predicted Answer: Үчүөр арыннатаахтыыр буолбута?
# --------------------------------------------------------------------------------
# Question: Ханна этэ-сиинэ накаастабыла аны туттуллубатый?
# True Answer: Арҕааҥҥы дойдулар үксүлэрэ
# Predicted Answer: Сыдыып, тудураллара буолар, бэлиһэ суох буолларга маннык аатыллыбыт тахсыбыт чигэлдэринэ с
# ...
# --------------------------------------------------------------------------------
# Question: Италия Конституционнай суута Коста ENEL-ы утары ирдэбилин сүтэрбитин туох биричиинэтин биэрбитэй?
# True Answer: национализация сокуона 1962 сыллаах буолан, уонна дуогабар 1958 сылтан күүһүгэр киирбит буолан, Коста ирдэбилэ суох этэ
# Predicted Answer: 1975 сыллаахха Италия Конституционнай Сууттара ENEL-га 100%-ка туруола сылдьан, хаһаҕынан иттэн б
# --------------------------------------------------------------------------------
# Question: Сэргэхсийэр ресурсаларга улахан интэриэһи үөскэтэр катализатор туох этэй?
# True Answer: энергетическэй кириисис
# Predicted Answer: Атыыны тылдьытарыына кэрээһинэр дьамбыттар кэлин суруйуута.
# Түмэн: Түгэ
# --------------------------------------------------------------------------------
# Question: Хас сыллаахха тропическай буурҕа Джексонвиллга түөрт күн устата уоту сүтэрбитэй?
# True Answer: 2008
# Predicted Answer: Чугаһыыр усулуобуйатын көрсүбүтэ уурулуобуйатын билигинэн үрдэрэй сүү
# --------------------------------------------------------------------------------
# Question: Сун династиятын кытта охсуһуу хас сыллаахха түмүктэммитэй?
# True Answer: 1279
# Predicted Answer: 1260—1271 сылларга Чингис-ханы өлбүтүн кэннэ кутулун биллибэтэ. Араб түмүкт
# --------------------------------------------------------------------------------
# Question: Британецтар Уильям Трент саҕана хаһан форт тутан саҕалаабыттарай?
# True Answer: 1754
# Predicted Answer: Бу туһугар билиэмнэтигэр бэрэнэн тэрийэйиитэ, өйүрө суохтуккуруоҕуллу
# --------------------------------------------------------------------------------
# Question: Лютер сиэртибэ оннугар мэссаны туох диэн ааттаабытай?
# True Answer: бэлэх
# Predicted Answer: Мэссаны туох диэн ааттаабытай. Олоҕун хошхоотута ыһыыга, онтон кыра илгэс көһ
# --------------------------------------------------------------------------------
# Question: Урут төһө тар колеялаах тимир суол линиялара былаас бас билиитигэр бааллара буолла?
# True Answer: биэс
# Predicted Answer: Былытааҕа барынньыка атында элбэх чугас сылларга киирбиттэрин биле, атын олохтоохто
# --------------------------------------------------------------------------------
# Question: Ploughshares тэрилтэ быстах кэмҥэ сабыллыбыт атын суолун ааттаа?
# True Answer: икки спутниковай антеннаны бүрүйэр улахан куполлартан биирдэстэрин салгынтан таһаарарга серптары туһанан
# Predicted Answer: Эрчииттэр эрчиигэ Плюшерсхаус Америка ССРэттэрэ (PLAS) 1992 сыл күнэрэ Таскуман
# --------------------------------------------------------------------------------
# Question: Денвер 24-10 ахсааны ылбытыгар оонньууга төһө бириэмэ хаалбытай?
# True Answer: 3:08
# Predicted Answer: Бо уҥара оҕуруктар уонна мөлтөрү, уонна өйүҥҥэ көстүүү
# --------------------------------------------------------------------------------
# Question: Сүрүн түөрт муннуктар хас түөрт муннуктаахтарый?
# True Answer: алта
# Predicted Answer: Сүрүн түөрт муннуктаахтарыҥ орто сылынан үгүллээктэринэн биллэр.
# Оло
# --------------------------------------------------------------------------------
# Question: 2000 сыллаахха, ABC туохха туһуламмыт интернет ситимнээх хампаанньаны саҕалаабыта?
# True Answer: төгүрүк бэлиэтэ
# Predicted Answer: Атын эргимтэ логотибын тула аналлаах интернет-рекламнай хампаанньана 1999-2002 сыллардааҕы бэлиэт
# --------------------------------------------------------------------------------
# Question: Полония Варшава 2000 сыл иннинэ дойду чемпионатыгар хаһан кыайбытай?
# True Answer: 1946
# Predicted Answer: Уппсала 1999 сыллаахха дойду чемпионатыгар хаһан кыайбытай?
# --------------------------------------------------------------------------------
# Question: Этии үксүн ханнык тылынан суруллубутай?
# True Answer: Латыын
# Predicted Answer: Нерөҥүҥэ атыылаабат олохтоохторо диэн баар. Олохтооччу уонна тухсунньуга уһуннь
# --------------------------------------------------------------------------------
# Question: Гугеноттарга тиийэллэригэр ханнык куораты дьиҥинэн биэрбиттэрэй?
# True Answer: Манакин куорат
# Predicted Answer: – Хоһооһунан арыллыбыт бэс ыйын 30 күнүгэр 1706 сыллаахха 400 олох
# --------------------------------------------------------------------------------
# Question: Судаарыстыбалар икки ардыларынааҕы суол систиэмэтэ хас сыллаахха тэриллибитэй?
# True Answer: 1950-с сыллар
# Predicted Answer: Кэттииртэһиилээһин дьоҕурдуу айаҕа кытта үрдүк сирдэрэ тэриллибит к
# --------------------------------------------------------------------------------
# Question: Сэргэхсийбит ленталарга хаартысканы тупсарар туһугар өҥү эбэн биэриэххэ сөп этэ дуу, эбэтэр хара-үрүҥ буолан хаалбыттара дуу?
# True Answer: хара уонна үрүҥ
# Predicted Answer: Дуу биир суох буолар буолан хаалбыттара дьарыктары үрдэтэ. Билигин үчүгэй таһымна
# --------------------------------------------------------------------------------
# Question: 2000 сылтан 2005 сылга диэри ойууру ыраастааһын тэтимэ сылга хас квадратнай миэтэрэ этэй?
# True Answer: 8,646 кв.
# Predicted Answer: Этэй сүүскэр оройуус ойууру ыраастааһыныһыныһа кулуппутугар тэһиэм
# --------------------------------------------------------------------------------
# Question: Адаптивнай иммуннай систиэмэ улахан суолтата суох эпитоптар силбэһиилэринэн куотар процессы туох диэн ааттыылларый?
# True Answer: антигеннай уларыйыы
# Predicted Answer: Доктор Ричард Шелли уонна профессор Томас Эванс 2011 сыл атырдьах ыйыгар тэриллибиттэр. Онньуоо�
# --------------------------------------------------------------------------------
# Question: Бериодтар тиис быһыытынан тугу тутталларый?
# True Answer: кытаанах ресницалар
# Predicted Answer: Кэлэр оҥойааччына таһынай тэҥнэр үөскэр кэлэр быһыытыгар, олоҕ
# --------------------------------------------------------------------------------
# Question: Римляннар ханнык племялар Хоту өттүттэн саба түһүөхтэрэ диэн куттаналлара буолла?
# True Answer: Пиктическай
# Predicted Answer: Ону саҕаларыттан 1 млн күн баран Саҥалара эмиэ Кини куттаналааҕа ахсыйахтарын ү
# --------------------------------------------------------------------------------
# Question: Фундаментальнай теорема уратытын харыстыыр ​​туһугар тоҕо киһини таһаарыахха нааданый?
# True Answer: тоҕо диэтэххэ, ханнык баҕарар факторизацияҕа 1 элбэх түбэлтэтин киллэриэххэ сөп
# Predicted Answer: Соруйаан таһыллыбыт үс бүтүн факторын үлэни үзэһэ үтүөхтэрэ,
# --------------------------------------------------------------------------------
# Question: Италияҕа, Византия империятыгар уонна Арменияҕа норманнар сүрүн өстөөхтөрө ким этэй?
# True Answer: Сельджук тюрктара
# Predicted Answer: Норманскай сулууспаҕа сиригэр билигин улахан үйэтин буолууну ахсаныы, уонна өстө
# --------------------------------------------------------------------------------
# Question: Супербоул XLIX ким кыайбытай?
# True Answer: Саҥа Англия Патриоттара
# Predicted Answer: Лидер ахсаанаҕа 2000 доллара тымнаҕынан көмүскэ!
# Плей-офф: Айтуустары быһаоччу
# --------------------------------------------------------------------------------
# Question: Плейстоцен кэмэ ханнык кэмҥэ буоларый?
# True Answer: Кватернернай
# Predicted Answer: Эппиеттик сиригэр кэнник кэм үһүс үһүс бириэмэ линиятын ордук кэмийэ кө
# --------------------------------------------------------------------------------
# Question: Оскуола хас үөрэх биригээдэтиттэн турарый?
# True Answer: уон биир
# Predicted Answer: Соҕуруоҕо, хастыбата, олоҕурор булгактарга төлөннөртүн быһыытынан
# --------------------------------------------------------------------------------
# Question: Икки хамаанданы бииртэн элбэх Суперкубокка илдьэ барбыт бастакы квартербек ким этэй?
# True Answer: Пейтон Мэннинг
# Predicted Answer: Айаллаахха тугуоҕун олоҕурдуохтаах эргийэтэ, арытынан уонна үөскөттэн курууктар
# --------------------------------------------------------------------------------
# Question: Ньюкасл университета 2000 сыллаахха тугу кыайбытай?
# True Answer: Sunday Times Сыл үнүбэрсиэтин бириэмийэтэ
# Predicted Answer: Аныма сүрүн чуоппуттанынан NUS student satisfaction surveyin 2006 сыллаахха "Нортумбрия университета 13-с сааһы
# --------------------------------------------------------------------------------
# Question: 1992 сыллаахха Великобритания үрдүнэн туох буолбутай?
# True Answer: политехникумнар саҥа үнүбэрсиэттэр буоллулар
# Predicted Answer: Бастыҥ олохтооччу олохторун өлөрүнэн, эмиэ аныма төрүттээччилэр.
# С
# --------------------------------------------------------------------------------
# Question: Бырабыыталыстыбаны эбэтэр итэҕэл систиэмэтин суулларарга көхтөөхтүк сорунуу баар буоллаҕына, ону туох диэн ааттыылларый?
# True Answer: Революционнай гражданскай истибэтэх буолуу
# Predicted Answer: Кини "бэйэ бэлитиичэскэй буолуу диэн төрөөхтүннэр" диэн тахса төрөө
# --------------------------------------------------------------------------------
# Question: Бырайыак туохха сөп түбэһиэхтээҕий?
# True Answer: зонирование уонна тутуу кодексын ирдэбиллэрэ
# Predicted Answer: Ойдуоттоохтаах уонна оророн сөп.
# Маннаҕа толоруо, ыйбыт буолуохтаах эмииттиэҕэ кэлэ
# --------------------------------------------------------------------------------
# Question: Ктенофор диэн гректии туох суолталааҕый?
# True Answer: тараахтаах
# Predicted Answer: Туох суолталааҕый диэн гректии эбэтэр тээпиннээх тиийэтэ олохтоохтубут киэһиттэр
# --------------------------------------------------------------------------------
# Question: Соҕурууҥҥу Калифорнияҕа олорор Анахайм Дакстан ураты НХЛ атын хамаандата кимий?
# True Answer: Лос-Анджелес Кингс
# Predicted Answer: Тускуу бэйэтэ суолтаммыт. Илгэс диэн билиһиттэрэ улаханнык өлбүннэр. Тэ
# --------------------------------------------------------------------------------
# Question: Киото боротокуола тугу быһаара сатаабыта буолла?
# True Answer: Климат уларыйыыта
# Predicted Answer: Быһааһын көрдөгүллүү үйэтин ситиһийэ тугу быһаарыгар таһымна
# --------------------------------------------------------------------------------
# Question: Ханнык оскуолалар ордук ergänzungschulen буолалларый?
# True Answer: идэтийбит
# Predicted Answer: Уһунньу 2010 сыллаахха сайдааҕа, биле олоҕурбуттара.
# Төптөр: Тугарга нэһ
# --------------------------------------------------------------------------------
# Question: Бастакы быһаччы быыбар хаһан буолбутай?
# True Answer: 1979
# Predicted Answer: Сокуону оҥоруу процессын уонна демократияга туһуллар
# Ол уонна быһыыста тэһинник үлэһэ
# --------------------------------------------------------------------------------
# Question: Таҥас хомуурунньугун кумааҕыга оҥоһуллубут үлэлэрэ ханнык отделга баалларый?
# True Answer: Тыл уонна ойуу
# Predicted Answer: Солокольникова Е. А. «Билдин»-га оҥоһуллубут таҥас эмиэ бу төп түгэнниирбит!
# Териг
# --------------------------------------------------------------------------------
# Question: Хубилай дьаһалтатыгар ханнык култууралар киирэллэрэ буолуой?
# True Answer: Хань кытайдар, хитаннар, джурченнар, монголлар уонна тибет буддистара
# Predicted Answer: Мунньуо, ааттаах киин билиһимнэрин тэҥҥэ күүстээн сылтан үөскэрин билэри
# --------------------------------------------------------------------------------
# Question: Судаарыстыбалар икки ардыларынааҕы суолга холбоммот саамай улахан куорат ханныгый?
# True Answer: Фресно
# Predicted Answer: Дээбитин үйэлэрин кыттыыр хомуусураттарын кыттыыр дьоҕуллубут буолбута.
# --------------------------------------------------------------------------------
# Question: Нигерия туһунан 2013 сыллаахха тахсыбыт отчуот үүнүүтэ тугу оҥорбутун көрдөрөрүй?
# True Answer: тиллибит
# Predicted Answer: Быһа элбэтиир дойдутта, суох буолуута санааллара.
# Единэһи: Анаалысты дьонно көрдөр
# --------------------------------------------------------------------------------
# Question: Уһук Илин хомуурунньуктарыгар чугаһаан төһө уус-уран оҥоһук киирбитий?
# True Answer: тахса 70,000
# Predicted Answer: Кытай улус утара Илин, Илиҥҥи Азия дойдуларыттан 7 млн. 500 тыһыынча сылтан тахса уус-
# --------------------------------------------------------------------------------
# Question: Иммуннай систиэмэни үөрэтии ханнык эйгэҕэ киирэрий?
# True Answer: Иммунология
# Predicted Answer: Гинекологулар үөрэтии Кандидоз?
# --------------------------------------------------------------------------------
# Question: Митчелл башнята Оксфорд башнятыгар майгынныыр гына оҥоһуллубутай?
# True Answer: Магдалина башнята
# Predicted Answer: Митчелл башнята Оксфорд башнятыгар майгынныырып үктүүлээбит, сүүүлээҕ
# --------------------------------------------------------------------------------
# Question: RP, BPP, PP, BQP, MA уонна PH уустук кылаастара ханна баар буолуохтарын сөбүй?
# True Answer: P уонна PSPACE икки ардыгар
# Predicted Answer: Үлэтигэр сүгэргэ RP, BPP, PP, BQP, MA, PH уустук кылаастар баалларын арыылааҕа
# --------------------------------------------------------------------------------
# Question: Джозеф Пристли хас сыллаахха кислороду билбитэй?
# True Answer: 1774
# Predicted Answer: Кислород диэриһиттэрин иэлээччилэрэ туппутугар, ол санаанан 1781 сыллаахха Уппсалаҕ
# --------------------------------------------------------------------------------
# Question: Хоту дойдулар илин эҥээр сирдэрин хонтуруоллааһыны аккаастыырга тугу туһаммыттарай?
# True Answer: Востоковедение
# Predicted Answer: Эндэҥҥэ, санаанын хаардар, түүннэрүүннэр үлэлээбиттэрэ биир
# --------------------------------------------------------------------------------
# Question: Грейнджер ырыынагын аһыллыытын бэлиэтиир аһылыкка төһө ыалдьыт сылдьыбытай?
# True Answer: 2000
# Predicted Answer: Соруйаанын уолуоҕа барыннаах сирэ. Хараҕаардыыта, эппиэт тостообуттара, тылсаллара ү
# --------------------------------------------------------------------------------
# Question: Кения коррупцияны хайдах бобор?
# True Answer: саҥа уонна тутулуга суох этика уонна коррупцияны утары хамыыһыйаны тэрийии
# Predicted Answer: Бу эппиэт бу куруук киһи Кения Үссэннэринэ Соруйаан кандидатын үгэлииһинэн икки кэ
# --------------------------------------------------------------------------------
# Question: Бронкос уонна Стилерс икки ардыларыгар дивизионнай эргиир кыайыылааҕа ханнык хамаанда этэй?
# True Answer: Бронкос
# Predicted Answer: Эдэрүүттэрэ, Стилерс уонна Патриоттар тыйаарга ахсынньыкүүнүн ардылар
# --------------------------------------------------------------------------------
# Question: UserDatagram Protocol тугу мэктиэлиирий
# True Answer: Виртуальнай ыҥырыы систиэмэтигэр ситим хостка даннайдары кэккэлэһэ тиэрдиини мэктиэлиир
# Predicted Answer: RFC 791, RFC 793, RFC 768, RFC 793bis, RFC 1122
# Хастабакка: RFC 1157, RFC 1174
# Назалаппыттара: UDP - С
# --------------------------------------------------------------------------------
# Question: Хотугу медицина офисын ким тэрийбитэй?
# True Answer: Иисус тылбаасчыт
# Predicted Answer: Эпидемикологията 1
# Правительство 2
# Административная структура 3
# Культура 4
# Государственные религиозные организации 5
# Физку
# --------------------------------------------------------------------------------
# Question: ARPNET уонна SITA хаһан үлэлээбиттэрэй
# True Answer: 1969
# Predicted Answer: Хосттар оруоллара сиксиэннэрэ СИТА-га, X.25-с ылан сүрүн систими туталаабыттара.
# Хастаамай
# --------------------------------------------------------------------------------
# Question: Кытай медицинатын ханнык философиялар тирэхтэрэй?
# True Answer: инь-ян уонна усин
# Predicted Answer: Кытай медицина эппиет буолар туһунан иитэрэй, ол бөрүйүөн анынан тахса үрдү
# --------------------------------------------------------------------------------
# Question: Цидиппидтар туох буолбатахтарын туһунан дакаастабыллар көрдөрөллөр?
# True Answer: монофилетическай
# Predicted Answer: Монофил буолбатахтар уонна атыннык эттэххэ дакаастабыллар көрдөрөллөр. Атынны
# --------------------------------------------------------------------------------
# Question: Ханнык немец баһылыга гугеноттар иммиграцияларын ыҥырбытай?
# True Answer: Фредерик Уильям
# Predicted Answer: Дьокуһулуобут диэн ааттара ССРО Кунньатаҕа Үрдүктэр буолбут уонна Германияныҥ иллэри ы
# --------------------------------------------------------------------------------
# Question: n ахсаан бастакы буоларын бигэргэтэр процесс аата?
# True Answer: боруобалааһын салаата
# Predicted Answer: Эппиэт - мэтээччи, чулуустарҕа мэлектэр инфериэйдийлэр. Баспыттар, кытта, инфериэй
# --------------------------------------------------------------------------------
